# %% [markdown]
# # Introduction
#
# In this notebook we demonstrate the use of a **Customized Word Embedding (Word2Vec)** DL technique to make trace link recovery between System Features and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each test case content as an entire document that must be returned to the query made

# %% [markdown]
# # Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd
import numpy as np
import pprint

from modules.models_runner.feat_br_models_runner import Feat_BR_Models_Runner
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import similarity_measures as sm
from modules.utils import br_feat_final_matrix_handler as b2f_handler

from matplotlib import pyplot as plt

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Load Datasets

# %%
bugreports = fd.Datasets.read_selected_bugreports_df()
features = fd.Datasets.read_features_df()
# Out:
# SelectedBugReports.shape: (91, 18)
# Features.shape: (19, 8)

# %% [markdown]
# # Running LSI Model - Exp-Vol UNION Oracle

# %%
models_runner_1 = Feat_BR_Models_Runner()

wv_model_1 = models_runner_1.run_cust_word2vec_model()

evaluator_1 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_volunteers_union_df().T)

sim_thresh = 0.0

wv_eval_t1 = evaluator_1.evaluate_model(model=wv_model_1, top_value=1, sim_threshold=sim_thresh)
wv_eval_t3 = evaluator_1.evaluate_model(model=wv_model_1, top_value=3, sim_threshold=sim_thresh)
wv_eval_t5 = evaluator_1.evaluate_model(model=wv_model_1, top_value=5, sim_threshold=sim_thresh)
wv_eval_t10 = evaluator_1.evaluate_model(model=wv_model_1, top_value=10, sim_threshold=sim_thresh)
# Out:
# Features.shape: (19, 8)
# SelectedBugReports.shape: (91, 18)
# Running Customized W2V model -----
# Expert and Volunteers Matrix UNION.shape: (91, 19)

# %% [markdown]
# # Similarity Matrix

# %%
aux_functions.highlight_df(wv_model_1.get_sim_matrix().iloc[0:23, 0:14])
# Out:
# <style  type="text/css" >
#     #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col0 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col1 {
#             background-color:  #0f880f;
#             color:  #f1f1f1;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col2 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col3 {
#             background-color:  #1f911f;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col4 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col5 {
#             background-color:  #1c8f1c;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col7 {
#             background-color:  #0b860b;
#             color:  #f1f1f1;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col9 {
#             background-color:  #4ba94b;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col10 {
#             background-color:  #48a848;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col11 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col12 {
#             background-color:  #198e19;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow0_col13 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col0 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col1 {
#             background-color:  #0e880e;
#             color:  #f1f1f1;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col2 {
#             background-color:  #80c780;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col3 {
#             background-color:  #4fac4f;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col4 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col5 {
#             background-color:  #5cb35c;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col6 {
#             background-color:  #42a442;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col7 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col8 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col9 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col10 {
#             background-color:  #80c780;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col11 {
#             background-color:  #62b662;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col12 {
#             background-color:  #299729;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow1_col13 {
#             background-color:  #61b661;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col0 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col1 {
#             background-color:  #2d992d;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col2 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col3 {
#             background-color:  #168c16;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col4 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col5 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col6 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col7 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col8 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col9 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col10 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col11 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col12 {
#             background-color:  #138a13;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow2_col13 {
#             background-color:  #389f38;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col0 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col2 {
#             background-color:  #91d091;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col3 {
#             background-color:  #49a849;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col4 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col5 {
#             background-color:  #5db35d;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col6 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col7 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col8 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col9 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col10 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col11 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col12 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow3_col13 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow4_col0 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow4_col1 {
#             background-color:  #7cc57c;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow4_col2 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_09461be2_92d0_11e9_b338_dd82d8c1b34erow4_col3 {
#             background-color:  #1f911f;
#             colo

# %% [markdown]
# # Analysis of BR x Feat Generated Traces

# %%
handler = b2f_handler.BR_Feat_Final_Matrix_Handler(mode=b2f_handler.HandlerMode.LOAD)
br_2_features_matrix_final = handler.add_mappings_1(columns_names=['Features_IDs_wv_t1_m',
                                                                   'Features_IDs_wv_t3_m',
                                                                   'Features_IDs_wv_t5_m',
                                                                   'Features_IDs_wv_t10_m',
                                                                   'Features_IDs_orc'],
                                                    trace_matrices=[wv_eval_t1['trace_links_df'],
                                                                    wv_eval_t3['trace_links_df'],
                                                                    wv_eval_t5['trace_links_df'],
                                                                    wv_eval_t10['trace_links_df'],
                                                                    evaluator_1.get_oracle_df()],
                                                    is_from_model=True)

br_2_features_matrix_final = handler.add_mappings_2(dest_columns_names=['f_names_wv_t1',
                                                                        'f_names_wv_t3',
                                                                        'f_names_wv_t5',
                                                                        'f_names_wv_t10',
                                                                        'f_names_orc'],
                                                   orig_columns_names=['Features_IDs_wv_t1_m',
                                                                       'Features_IDs_wv_t3_m',
                                                                       'Features_IDs_wv_t5_m',
                                                                       'Features_IDs_wv_t10_m',
                                                                       'Features_IDs_orc'])
br_2_features_matrix_final.head(10)
# Out:
# SelectedBugReports.shape: (91, 18)
# Features.shape: (19, 8)
# BR_2_Features Matrix Final.shape: (91, 5)
#                                                     bug_title  \
# Bug_Number
# 1248267     Right click on bookmark item of "Recently Book...
# 1248268               Unable to disable "Recently bookmarked"
# 1257087     Middle mouse click on history item would not open
# 1264988     Scrollbar appears for a moment in the new Awes...
# 1267480     Intermittent browser/components/preferences/in...
# 1267501     New Private Browsing start-page overflows off ...
# 1269348     Show last sync date tooltip on Synced Tabs sid...
# 1269485     New Private Browsing start-page has white/gray...
# 1270274     Intermittent browser_share.jsuncaught exceptio...
# 1270983     Intermittent browser_contextmenu.jsTest timed ...
#
#            Features_IDs_exp_m Features_IDs_vol_m Features_IDs_exp_vol_union_m  \
# Bug_Number
# 1248267                     6                  6                            6
# 1248268                                        4                            4
# 1257087
# 1264988                     1                  1                            1
# 1267480
# 1267501                     3                                               3
# 1269348
# 1269485                     3                                               3
# 1270274
# 1270983                     6                  6                            6
#
#            Features_IDs_exp_vol_intersec_m Features_IDs_wv_t1_m  \
# Bug_Number
# 1248267                                  6                    6
# 1248268                                                       4
# 1257087                                                       6
# 1264988                                  1                    9
# 1267480                                                       5
# 1267501                                                      12
# 1269348                                                       1
# 1269485                                                      12
# 1270274                                                       5
# 1270983                                  6                    6
#
#            Features_IDs_wv_t3_m Features_IDs_wv_t5_m  \
# Bug_Number
# 1248267                   1 6 7          1 6 7 12 14
# 1248268                   1 2 4           1 2 4 9 19
# 1257087                   1 6 7          1 6 7 12 14
# 1264988                   1 3 9           1 3 5 9 16
# 1267480                 5 10 11         5 9 10 11 13
# 1267501                  7 8 12           3 7 8 9 12
# 1269348                   1 4 6           1 2 4 6 12
# 1269485                  1 7 12           1 6 7 9 12
# 1270274                 5 10 16        5 10 14 16 19
# 1270983                   5 6 7           1 5 6 7 10
#
#                 Features_IDs_wv_t10_m Features_IDs_orc  \
# Bug_Number
# 1248267       1 2 6 7 8 9 10 12 14 19                6
# 1248268       1 2 3 4 8 9 12 14 17 19                4
# 1257087       1 5 6 7 8 9 10 12 14 19
# 1264988       1 3 4 5 8 9 12 14 16 18                1
# 1267480     5 6 7 9 10 11 12 13 14 19
# 1267501       1 3 6 7 8 9 12 14 18 19                3
# 1269348        1 2 4 6 7 8 9 10 12 14
# 1269485        1 2 3 6 7 8 9 12 14 19                3
# 1270274                 5 10 14 16 19
# 1270983       1 5 6 7 8 9 10 11 12 14                6
#
#                         f_names_wv_t1  \
# Bug_Number
# 1248267              [[context_menu]]
# 1248268     [[browser_customization]]
# 1257087              [[context_menu]]
# 1264988                 [[tts_in_rm]]
# 1267480                [[pdf_viewer]]
# 1267501          [[pointer_lock_api]]
# 1269348           [[new_awesome_bar]]
# 1269485          [[pointer_lock_api]]
# 1270274                [[pdf_viewer]]
# 1270983              [[context_menu]]
#
#                                                 f_names_wv_t3  \
# Bug_Number
# 1248267       [[new_awesome_bar], [context_menu], [w10_comp]]
# 1248268     [[new_awesome_bar], [windows_child_mode], [bro...
# 1257087       [[new_awesome_bar], [context_menu], [w10_comp]]
# 1264988     [[new_awesome_bar], [apz_async_scrolling], [tt...
# 1267480     [[pdf_viewer], [webgl_comp], [video_and_canvas...
# 1267501     [[w10_comp], [tts_in_desktop], [pointer_lock_a...
# 1269348     [[new_awesome_bar], [browser_customization], [...
# 1269485     [[new_awesome_bar], [w10_comp], [pointer_lock_...
# 1270274                [[pdf_viewer], [webgl_comp], [webgl2]]
# 1270983            [[pdf_viewer], [context_menu], [w10_comp]]
#
#                                                 f_names_wv_t5  \
# Bug_Number
# 1248267     [[new_awesome_bar], [context_menu], [w10_comp]...
# 1248268     [[new_awesome_bar], [windows_child_mode], [bro...
# 1257087     [[new_awesome_bar], [context_menu], [w10_comp]...
# 1264988     [[new_awesome_bar], [apz_async_scrolling], [pd...
# 1267480     [[pdf_viewer], [tts_in_rm], [webgl_comp], [vid...
# 1267501     [[apz_async_scrolling], [w10_comp], [tts_in_de...
# 1269348     [[new_awesome_bar], [windows_child_mode], [bro...
# 1269485     [[new_awesome_bar], [context_menu], [w10_comp]...
# 1270274     [[pdf_viewer], [webgl_comp], [zoom_indicator],...
# 1270983     [[new_awesome_bar], [pdf_viewer], [context_men...
#
#                                                f_names_wv_t10  \
# Bug_Number
# 1248267     [[new_awesome_bar], [windows_child_mode], [con...
# 1248268     [[new_awesome_bar], [windows_child_mode], [apz...
# 1257087     [[new_awesome_bar], [pdf_viewer], [context_men...
# 1264988     [[new_awesome_bar], [apz_async_scrolling], [br...
# 1267480     [[pdf_viewer], [context_menu], [w10_comp], [tt...
# 1267501     [[new_awesome_bar], [apz_async_scrolling], [co...
# 1269348     [[new_awesome_bar], [windows_child_mode], [bro...
# 1269485     [[new_awesome_bar], [windows_child_mode], [apz...
# 1270274     [[pdf_viewer], [webgl_comp], [zoom_indicator],...
# 1270983     [[new_awesome_bar], [pdf_viewer], [context_men...
#
#                           f_names_orc
# Bug_Number
# 1248267              [[context_menu]]
# 1248268     [[browser_customization]]
# 1257087                            []
# 1264988           [[new_awesome_bar]]
# 1267480                            []
# 1267501       [[apz_async_scrolling]]
# 1269348                            []
# 1269485       [[apz_async_scrolling]]
# 1270274                            []
# 1270983              [[context_menu]]

# %% [markdown]
# # Analysis of Precision and Recall

# %% [markdown]
# ## Union Strategy

# %%
results_1 = evaluator_1.run_evaluator(models=[wv_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_1.plot_evaluations_2(title='WordVector Evaluation | Exp-Vol UNION', results=results_1)
# Out:
# Evaluating CUST_WORDVECTOR Model -----
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-98d53214c8fa> in <module>
# ----> 1 results_1 = evaluator_1.run_evaluator(models=[wv_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
#       2 evaluator_1.plot_evaluations_2(title='WordVector Evaluation | Exp-Vol UNION', results=results_1)
#
# ~/anaconda3/envs/trace-link-recovery-study/modules/utils/model_evaluator.py in run_evaluator(self, verbose, file, models, top_values, sim_thresholds)
#      88                                                              top_value=top_value,
#      89                                                              sim_threshold=s_threshold,
# ---> 90                                                              ref_name=ref_name), ignore_index=True)
#      91         return evals
#      92
#
# ~/anaconda3/envs/trace-link-recovery-study/modules/utils/model_evaluator.py in evaluate_model(self, verbose, file, model, top_value, sim_threshold, ref_name)
#      53         fn = len(aux_functions.get_false_negatives(oracle_df = self.oracle, output_df = trace_links_df))
#      54
# ---> 55         mean_precision = tp / (tp + fp)
#      56         mean_recall = tp / (tp + fn)
#      57
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Intersection Strategy

# %%
evaluator_2 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_volunteers_intersec_df().T)
results_2 = evaluator_2.run_evaluator(models=[wv_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_2.plot_evaluations_2(title='WordVector Evaluation | Exp-Vol INTERSECTION', results=results_2)
# Out:
# Expert and Volunteers Matrix INTERSEC.shape: (91, 19)
# Evaluating CUST_WORDVECTOR Model -----
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-fa606126d05c> in <module>
#       1 evaluator_2 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_volunteers_intersec_df().T)
# ----> 2 results_2 = evaluator_2.run_evaluator(models=[wv_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
#       3 evaluator_2.plot_evaluations_2(title='WordVector Evaluation | Exp-Vol INTERSECTION', results=results_2)
#
# ~/anaconda3/envs/trace-link-recovery-study/modules/utils/model_evaluator.py in run_evaluator(self, verbose, file, models, top_values, sim_thresholds)
#      88                                                              top_value=top_value,
#      89                                                              sim_threshold=s_threshold,
# ---> 90                                                              ref_name=ref_name), ignore_index=True)
#      91         return evals
#      92
#
# ~/anaconda3/envs/trace-link-recovery-study/modules/utils/model_evaluator.py in evaluate_model(self, verbose, file, model, top_value, sim_threshold, ref_name)
#      53         fn = len(aux_functions.get_false_negatives(oracle_df = self.oracle, output_df = trace_links_df))
#      54
# ---> 55         mean_precision = tp / (tp + fp)
#      56         mean_recall = tp / (tp + fn)
#      57
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Expert-Only Strategy

# %%
evaluator_3 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_df().T)
results_3 = evaluator_3.run_evaluator(models=[wv_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_3.plot_evaluations_2(title='WordVector Evaluation | Expert-Only', results=results_3)

# %% [markdown]
# ## Volunteers-Only Strategy

# %%
evaluator_4 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_volunteers_df().T)
results_4 = evaluator_4.run_evaluator(models=[wv_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_4.plot_evaluations_2(title='WordVector Evaluation | Volunteers-Only', results=results_4)

# %% [markdown]
# ### Means of Metrics
#
# Considering **TOP** values (1,3,5) and **SIMILARITY THRESHOLDS** values range(0.0,0.9)

# %%
print("Mean Precision: {:2.3}".format(np.mean(results_4.perc_precision)))
print("Mean Recall: {:2.3}".format(np.mean(results_4.perc_recall)))
print("Mean F-Score: {:2.3}".format(np.mean(results_4.perc_fscore)))
