# %% [markdown]
# # Introduction - Using COSINE Metric
#
# In this notebook we demonstrate the use of **LSI (Latent Semantic Indexing)** technique of Information Retrieval context to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each use case content as an entire document that must be returned to the query made

# %% [markdown]
# # Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd

from modules.models_runner.tc_br_models_runner import TC_BR_Runner
from modules.models_runner.tc_br_models_runner import TC_BR_Models_Hyperp
from modules.utils import aux_functions
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import tokenizers as tok

from modules.models.lsi import LSI

from IPython.display import display

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Load Datasets

# %%
tcs = [x for x in range(37,59)]
orc = fd.Tc_BR_Oracles.read_oracle_expert_df()
orc_subset = orc[orc.index.isin(tcs)]
#aux_functions.highlight_df(orc_subset)
# Out:
# OracleExpert.shape: (195, 91)

# %%
tcs = [13,37,60]
brs = [1267501]

testcases = fd.Datasets.read_testcases_df()
testcases = testcases[testcases.TC_Number.isin(tcs)]
bugreports = fd.Datasets.read_selected_bugreports_df()
bugreports = bugreports[bugreports.Bug_Number.isin(brs)]

print('tc.shape: {}'.format(testcases.shape))
print('br.shape: {}'.format(bugreports.shape))
# Out:
# TestCases.shape: (195, 12)
# SelectedBugReports.shape: (91, 18)
# tc.shape: (3, 12)
# br.shape: (1, 18)

# %%
print(bugreports.iloc[0,:].Summary)
bugreports
# Out:
# New Private Browsing start-page overflows off the *left side of the window* (making content unscrollable) for small window sizes
#    Bug_Number                                            Summary     Platform  \
# 6     1267501  New Private Browsing start-page overflows off ...  Unspecified
#
#           Component    Version         Creation_Time   Whiteboard  \
# 6  Private Browsing  48 Branch  2016-04-26T01:12:11Z  [fxprivacy]
#
#   QA_Whiteboard                                 First_Comment_Text  \
# 6           NaN  STR:  1. Open a new private browsing window.  ...
#
#   First_Comment_Creation_Time    Status  Product Priority Resolution Severity  \
# 6        2016-04-26T01:12:11Z  RESOLVED  Firefox       P1      FIXED   normal
#
#    Is_Confirmed         br_name  \
# 6          True  BR_1267501_SRC
#
#                                              br_desc
# 6  1267501 New Private Browsing start-page overfl...

# %%
testcases
# Out:
#     TC_Number                         TestDay  Feature_ID  \
# 12         13  20160603 + 20160624 + 20161014           1
# 36         37             20160603 + 20160708           3
# 59         60                        20160722           4
#
#           Firefox_Feature              Gen_Title  Crt_Nr  \
# 12        New Awesome Bar     Awesome Bar Search       1
# 36  APZ - Async Scrolling  APZ - Async Scrolling       1
# 59  Browser Customization  browser customization       2
#
#                               Title  \
# 12                    Default State
# 36   Scroll through a long web page
# 59  Install and use complete themes
#
#                                         Preconditions  \
# 12                                                NaN
# 36  - make sure layers.async-pan-zoom.enabled is t...
# 59                                                NaN
#
#                                                 Steps  \
# 12       1. Launch Firefox.\t\n2. No AwesomeBar Entry
# 36  1. Launch Firefox.\t\n2. Open: https://en.wiki...
# 59  1. Install a few complete themes.\n2. Restart ...
#
#                                       Expected_Result    tc_name  \
# 12  1. Firefox launches without any issues.\n2. UR...  TC_13_TRG
# 36  1. \n2.\n3. The scrolling is smooth, without a...  TC_37_TRG
# 59  1. The user is able to initiate installation p...  TC_60_TRG
#
#                                               tc_desc
# 12  13 20160603 + 20160624 + 20161014 1 New Awesom...
# 36  37 20160603 + 20160708 3 APZ - Async Scrolling...
# 59  60 20160722 4 Browser Customization browser cu...

# %% [markdown]
# # Running LSI Model

# %%
corpus = testcases.tc_desc
query = bugreports.br_desc
test_cases_names = testcases.tc_name
bug_reports_names = bugreports.br_name

lsi_hyperp = TC_BR_Models_Hyperp.get_lsi_model_hyperp()
lsi_model = LSI(**lsi_hyperp)
lsi_model.set_name('LSI_Model_TC_BR')
lsi_model.recover_links(corpus, query, test_cases_names, bug_reports_names)

# %%
lsi_model.get_sim_matrix().shape
# Out:
# (3, 1)

# %%
sim_matrix = lsi_model.get_sim_matrix()
aux_functions.highlight_df(sim_matrix)
# Out:
# <style  type="text/css" >
#     #T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbd" ><thead>    <tr>        <th class="index_name level0" >br_name</th>        <th class="col_heading level0 col0" >BR_1267501_SRC</th>    </tr>    <tr>        <th class="index_name level0" >tc_name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row0" class="row_heading level0 row0" >TC_13_TRG</th>
#                         <td id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0" class="data row0 col0" >0.462094</td>
#             </tr>
#             <tr>
#                         <th id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row1" class="row_heading level0 row1" >TC_37_TRG</th>
#                         <td id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0" class="data row1 col0" >0.948398</td>
#             </tr>
#             <tr>
#                         <th id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row2" class="row_heading level0 row2" >TC_60_TRG</th>
#                         <td id="T_bde34f84_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0" class="data row2 col0" >0.0642657</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### TF-IDF Application

# %%
print(bugreports.Summary.values[0])
print(bugreports.First_Comment_Text.values[0])
# Out:
# New Private Browsing start-page overflows off the *left side of the window* (making content unscrollable) for small window sizes
# STR:  1. Open a new private browsing window.  2. Resize the window to be skinny, say 300-400px wide.  3. Try to scroll around horizontally to read the page's contents (using the scrollbars).  ACTUAL RESULTS: - If you scroll all the way to the left, you'll see that the page's contents overflow off the left side of the viewport, to the extent that they're unscrollable and hence unreadable. - If you scroll all the way to the right, you'll see that the page's background-color ends abruptly, and some text protrudes past that.   EXPECTED RESULTS: * Contents should be scrollable/readable. * No awkward background-color-ending in the region of the viewport that is scrollable.

# %%
q = query.values[0]

tok = lsi_model.vectorizer.tokenizer
words_list = tok.__call__(q)

from collections import Counter
wordcount = Counter(words_list).most_common()

df = pd.DataFrame(columns=['term','tf',''])

print(wordcount)
# Out:
# [('private', 3),
#  ('browsing', 3),
#  ('content', 3),
#  ('window', 3),
#  ('scroll', 3),
#  ('page', 3),
#  ('new', 2),
#  ('overflow', 2),
#  ('side', 2),
#  ('unscrollable', 2),
#  ('results', 2),
#  ('if', 2),
#  ('way', 2),
#  ('left', 2),
#  ('see', 2),
#  ('viewport', 2),
#  ('making', 1),
#  ('small', 1),
#  ('size', 1),
#  ('unspecified', 1),
#  ('branch', 1),
#  ('fxprivacy', 1),
#  ('nan', 1),
#  ('str', 1),
#  ('open', 1),
#  ('resize', 1),
#  ('skinny', 1),
#  ('say', 1),
#  ('wide', 1),
#  ('try', 1),
#  ('around', 1),
#  ('horizontally', 1),
#  ('read', 1),
#  ('using', 1),
#  ('scrollbars', 1),
#  ('actual', 1),
#  ('extent', 1),
#  ('hence', 1),
#  ('unreadable', 1),
#  ('right', 1),
#  ('end', 1),
#  ('abruptly', 1),
#  ('text', 1),
#  ('protrudes', 1),
#  ('past', 1),
#  ('expected', 1),
#  ('contents', 1),
#  ('no', 1),
#  ('awkward', 1),
#  ('region', 1),
#  ('scrollable', 1),
#  ('resolved', 1),
#  ('firefox', 1),
#  ('fixed', 1),
#  ('normal', 1),
#  ('true', 1)]

# %%
lsi_model.get_svd_matrix().shape
# Out:
# (3, 3)

# %%
svd_matrix = pd.DataFrame(lsi_model.get_svd_matrix())
#svd_matrix.index = test_cases_names
aux_functions.highlight_df(svd_matrix)
# Out:
# <style  type="text/css" >
#     #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow0_col1 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0 {
#             background-color:  #058205;
#             color:  #f1f1f1;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow2_col2 {
#             background-color:  #89cc89;
#             color:  #000000;
#         }</style><table id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0" class="data row0 col0" >0.763211</td>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow0_col2" class="data row0 col2" >0.646149</td>
#             </tr>
#             <tr>
#                         <th id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0" class="data row1 col0" >0.750932</td>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow1_col1" class="data row1 col1" >-0.178656</td>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow1_col2" class="data row1 col2" >-0.635753</td>
#             </tr>
#             <tr>
#                         <th id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0" class="data row2 col0" >0.136353</td>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow2_col1" class="data row2 col1" >0.983912</td>
#                         <td id="T_bde83ee0_7dbd_11e9_b987_69c3ce6c0bbdrow2_col2" class="data row2 col2" >-0.115439</td>
#             </tr>
#     </tbody></table>

# %%
len(lsi_model.vectorizer.get_feature_names())
# Out:
# 65

# %%
tokenizer = tok.WordNetBased_LemmaTokenizer()
tokens = [tokenizer.__call__(doc) for doc in bugreports.br_desc]
final_tokens = set()
for token_list in tokens:
    for t in token_list:
        final_tokens.add(t)

#final_tokens = final_tokens.intersection(set())       
final_tokens = sorted(list(final_tokens))
print(final_tokens)

dff = pd.DataFrame(final_tokens)
print(dff.shape)
#display(dff)
# Out:
# ['abruptly', 'actual', 'around', 'awkward', 'branch', 'browsing', 'content', 'contents', 'end', 'expected', 'extent', 'firefox', 'fixed', 'fxprivacy', 'hence', 'horizontally', 'if', 'left', 'making', 'nan', 'new', 'no', 'normal', 'open', 'overflow', 'page', 'past', 'private', 'protrudes', 'read', 'region', 'resize', 'resolved', 'results', 'right', 'say', 'scroll', 'scrollable', 'scrollbars', 'see', 'side', 'size', 'skinny', 'small', 'str', 'text', 'true', 'try', 'unreadable', 'unscrollable', 'unspecified', 'using', 'viewport', 'way', 'wide', 'window']
# (56, 1)

# %%
X = lsi_model.vectorizer.transform(bugreports.br_desc)
df1 = pd.DataFrame(X.T.toarray())
df1.index = lsi_model.vectorizer.get_feature_names()
df1.rename(columns={0:'BR_1267501_SRC'}, inplace=True)
print(df1.shape)
aux_functions.highlight_df(df1)
# Out:
# (65, 1)
# <style  type="text/css" >
#     #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow10_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow11_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow12_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow13_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow14_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow15_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow16_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow17_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow18_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow19_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow20_col0 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow21_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow22_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow23_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow24_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow25_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow26_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow27_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow28_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow29_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow30_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow31_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow32_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow33_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow34_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow35_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow36_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow37_col0 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow38_col0 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow39_col0 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow40_col0 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow41_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow42_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow43_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow44_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow45_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow46_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow47_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow48_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow49_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow50_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow51_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow52_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow53_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow54_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow55_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow56_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow57_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow58_col0 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_bdf671c2_7dbd_11e9_b987_69c3ce6c0bbdrow59_col0 {
#             background

# %%
query_vec = lsi_model._query_vector
query_vec = pd.DataFrame(query_vec)
query_vec.index = bug_reports_names
query_vec
# Out:
#                        0         1         2
# br_name
# BR_1267501_SRC  0.434341 -0.050055 -0.175978

# %%
from sklearn.metrics import pairwise
results = pd.DataFrame(pairwise.cosine_similarity(X=svd_matrix, Y=query_vec))
results.index = test_cases_names
results.rename(columns={0:bug_reports_names.values[0]}, inplace=True)
aux_functions.highlight_df(results)
# Out:
# <style  type="text/css" >
#     #T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BR_1267501_SRC</th>    </tr>    <tr>        <th class="index_name level0" >tc_name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row0" class="row_heading level0 row0" >TC_13_TRG</th>
#                         <td id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0" class="data row0 col0" >0.462094</td>
#             </tr>
#             <tr>
#                         <th id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row1" class="row_heading level0 row1" >TC_37_TRG</th>
#                         <td id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0" class="data row1 col0" >0.948398</td>
#             </tr>
#             <tr>
#                         <th id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdlevel0_row2" class="row_heading level0 row2" >TC_60_TRG</th>
#                         <td id="T_bdfb8022_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0" class="data row2 col0" >0.0642657</td>
#             </tr>
#     </tbody></table>

# %%
import numpy as np

tokenizer = tok.WordNetBased_LemmaTokenizer()
tokens = [tokenizer.__call__(doc) for doc in testcases.tc_desc]
final_tokens = []
for token_list in tokens:
    for t in token_list:
        final_tokens.append(t)

print(np.unique(final_tokens))
print(len(np.unique(final_tokens)))
# Out:
# ['able' 'active' 'all' 'appearance' 'appears' 'apz' 'arrow' 'async'
#  'awesome' 'awesomebar' 'bar' 'browser' 'complete' 'config' 'ctrl'
#  'customization' 'default' 'disabled' 'display' 'enabled' 'entry'
#  'firefox' 'home' 'http' 'initiate' 'install' 'installation' 'installed'
#  'issue' 'jerkiness' 'key' 'latest' 'launch' 'lightweight' 'long' 'make'
#  'manager' 'mouse' 'nan' 'new' 'no' 'once' 'open' 'page' 'previous'
#  'previously' 'process' 'rendering' 'replaces' 'restart' 'restarted'
#  'scroll' 'scrolling' 'search' 'section' 'set' 'smooth' 'space' 'state'
#  'sure' 'the' 'theme' 'true' 'url' 'use' 'user' 'using' 'web' 'wheel'
#  'without']
# 70

# %% [markdown]
# Term-by-Document Matrix - SVD Matrix

# %%
df = pd.DataFrame(lsi_model.svd_model.components_.T)
df.index = lsi_model.vectorizer.get_feature_names()
df.rename(columns={0:'TC_13_TRG',1:'TC_37_TRG',2:'TC_60_TRG'}, inplace=True)
print(df.shape)
aux_functions.highlight_df(df)
# Out:
# (65, 3)
# <style  type="text/css" >
#     #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow0_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow0_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow1_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow1_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow2_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow2_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow3_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow3_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow4_col0 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow4_col1 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow4_col2 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow5_col0 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow5_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow5_col2 {
#             background-color:  #a0d9a0;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow6_col0 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow6_col1 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow6_col2 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow7_col0 {
#             background-color:  #239323;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow7_col1 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow7_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow8_col0 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow8_col1 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow8_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow9_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow9_col1 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow9_col2 {
#             background-color:  #53ae53;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow10_col0 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow10_col1 {
#             background-color:  #75c175;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow10_col2 {
#             background-color:  #8fcf8f;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow11_col0 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow11_col1 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow11_col2 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow12_col0 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow12_col1 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow12_col2 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow13_col0 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow13_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow13_col2 {
#             background-color:  #a0d9a0;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow14_col0 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow14_col1 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow14_col2 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow15_col0 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow15_col1 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow15_col2 {
#             background-color:  #51ad51;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow16_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow16_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow16_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow17_col0 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow17_col1 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow17_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow18_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow18_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow18_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow19_col0 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow19_col1 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_be0f4986_7dbd_11e9_b987_69c3ce6c0bbdrow19_col2 {
#             background-color:  #3fa33f;

# %%
lsi_model.docs_feats_df
# Out:
#                                                               mrw  dl
# TC_13_TRG         [awesome, launch, bar, firefox, entry, display]  23
# TC_37_TRG              [key, scrolling, scroll, sure, apz, async]  43
# TC_60_TRG       [theme, complete, browser, installation, insta...  52
# BR_1267501_SRC             [scroll, page, new, using, true, open]  78
