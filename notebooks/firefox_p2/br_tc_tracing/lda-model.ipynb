# %% [markdown]
# # Introduction
#
# In this notebook we demonstrate the use of **LDA (Latent Dirichlet Allocation)** generative statistical model for Information Retrieval technique to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each test case content as an entire document that must be returned to the query made

# %% [markdown]
# ## Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd
import numpy as np

from dit.divergences import jensen_shannon_divergence

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from modules.utils import plots
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import tokenizers as tok
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval

from modules.models.lda import LDA
from modules.models.model_hyperps import LDA_Model_Hyperp

from IPython.display import display

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# ## Load Dataset

# %%
test_cases_df = fd.read_testcases_df()
bug_reports_df = fd.read_bugreports_df()

corpus = test_cases_df.tc_desc
query = bug_reports_df.br_desc

test_cases_names = test_cases_df.tc_name
bug_reports_names = bug_reports_df.br_name

orc = fd.read_oracle_expert_volunteers_df()
# Out:
# TestCases.shape: (207, 12)
# BugReports.shape: (93, 19)
# Oracle.shape: (207, 93)

# %% [markdown]
# ## Evaluate Recovering Efficiency

# %% [markdown]
# In order to evaluate the efficiency of the algorithm tested (LSI), we use common metrics applied in the field of IR:
#
#     * Precision
#     * Recall
#     * F1-score

# %% [markdown]
# ### Analysis with Default Values of LDA Model

# %%
model = LDA()
model.recover_links(corpus, query, test_cases_names, bug_reports_names)
evaluator = m_eval.ModelEvaluator(orc, model)
evaluator.evaluate_model(verbose=True)
# Out:
# {'Measures': {'Mean FScore of LDA': 0.011351909184726523,
#               'Mean Precision of LDA': 0.050179211469534045,
#               'Mean Recall of LDA': 0.006481963232743671},
#  'Setup': [{'Name': 'LDA'},
#            {'Similarity Measure and Minimum Threshold': ('jsd', 0.3)},
#            {'Top Value': 3},
#            {'LDA Model': {'batch_size': 128,
#                           'doc_topic_prior': None,
#                           'evaluate_every': -1,
#                           'learning_decay': 0.7,
#                           'learning_method': 'batch',
#                           'learning_offset': 10.0,
#                           'max_doc_update_iter': 100,
#                           'max_iter': 10,
#                           'mean_change_tol': 0.001,
#                           'n_components': 10,
#                           'n_jobs': -1,
#                           'n_topics': None,
#                           'perp_tol': 0.1,
#                           'random_state': None,
#                           'topic_word_prior': None,
#                           'total_samples': 1000000.0,
#                           'verbose': 0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': None,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}

# %% [markdown]
# ## Running LDA Model

# %%
# %%time

lda_hyperp = {
    LDA_Model_Hyperp.TOP.value : 100,
    LDA_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : ('cosine',.75),
    LDA_Model_Hyperp.LDA_MODEL_N_COMPONENTS.value: 50,
    LDA_Model_Hyperp.LDA_MODEL_RANDOM_STATE.value : 2,
    LDA_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: (1,1),
    LDA_Model_Hyperp.VECTORIZER.value : TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True),
    LDA_Model_Hyperp.VECTORIZER_TOKENIZER.value : tok.PorterStemmerBased_Tokenizer() 
}

lda_model = LDA(**lda_hyperp)
lda_model.set_name('LDA_Model_AllData')
lda_model.recover_links(corpus, query, test_cases_names, bug_reports_names)

print("\nModel Evaluation -------------------------------------------")
evaluator = m_eval.ModelEvaluator(orc, lda_model)
evaluator.evaluate_model(verbose=True)
# Out:
# Model Evaluation -------------------------------------------
# {'Measures': {'Mean FScore of LDA_Model_AllData': 0.08542313017991841,
#               'Mean Precision of LDA_Model_AllData': 0.05509820627037862,
#               'Mean Recall of LDA_Model_AllData': 0.2786315363332886},
#  'Setup': [{'Name': 'LDA_Model_AllData'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.75)},
#            {'Top Value': 100},
#            {'LDA Model': {'batch_size': 128,
#                           'doc_topic_prior': None,
#                           'evaluate_every': -1,
#                           'learning_decay': 0.7,
#                           'learning_method': 'batch',
#                           'learning_offset': 10.0,
#                           'max_doc_update_iter': 100,
#                           'max_iter': 10,
#                           'mean_change_tol': 0.001,
#                           'n_components': 50,
#                           'n_jobs': -1,
#                           'n_topics': None,
#                           'perp_tol': 0.1,
#                           'random_state': 2,
#                           'topic_word_prior': None,
#                           'total_samples': 1000000.0,
#                           'verbose': 0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.PorterStemmerBased_Tokenizer object at 0x7f480007b780>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# CPU times: user 3.8 s, sys: 52 ms, total: 3.85 s
# Wall time: 1.89 s

# %%
aux_functions.highlight_df(orc.iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622a_35dd_11e9_8ce7_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lda_model.get_trace_links_df().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col1 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col2 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col4 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col2 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col2 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col2 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col2 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col2 {
#             background-color:  #008000;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622b_35dd_11e9_8ce7_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lda_model.get_sim_matrix().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col0 {
#             background-color:  #269526;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col1 {
#             background-color:  #008000;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col2 {
#             background-color:  #1d901d;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col3 {
#             background-color:  #64b764;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col4 {
#             background-color:  #0c860c;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col5 {
#             background-color:  #43a543;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row0_col6 {
#             background-color:  #5fb55f;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col0 {
#             background-color:  #d4f6d4;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col1 {
#             background-color:  #d2f4d2;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col2 {
#             background-color:  #6dbc6d;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col3 {
#             background-color:  #dbf9db;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col4 {
#             background-color:  #cff3cf;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col5 {
#             background-color:  #cef2ce;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row1_col6 {
#             background-color:  #dcfadc;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col0 {
#             background-color:  #acdfac;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col1 {
#             background-color:  #a8dda8;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col2 {
#             background-color:  #43a543;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col3 {
#             background-color:  #bde9bd;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col4 {
#             background-color:  #9ed89e;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col5 {
#             background-color:  #9bd69b;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row2_col6 {
#             background-color:  #bfeabf;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col0 {
#             background-color:  #e3fee3;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col2 {
#             background-color:  #8bcd8b;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col3 {
#             background-color:  #e3fee3;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row3_col6 {
#             background-color:  #e3fee3;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col0 {
#             background-color:  #9cd69c;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col1 {
#             background-color:  #269526;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col2 {
#             background-color:  #2b982b;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col3 {
#             background-color:  #b6e5b6;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col4 {
#             background-color:  #4fac4f;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col5 {
#             background-color:  #91d091;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row4_col6 {
#             background-color:  #b5e4b5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col2 {
#             background-color:  #86ca86;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col0 {
#             background-color:  #c2ebc2;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col1 {
#             background-color:  #e1fde1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col2 {
#             background-color:  #94d294;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col3 {
#             background-color:  #d1f4d1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col4 {
#             background-color:  #b1e2b1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col5 {
#             background-color:  #a2daa2;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row6_col6 {
#             background-color:  #d1f4d1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col0 {
#             background-color:  #5eb45e;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col1 {
#             background-color:  #8dce8d;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col2 {
#             background-color:  #0e880e;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col3 {
#             background-color:  #98d498;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col4 {
#             background-color:  #7cc57c;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col5 {
#             background-color:  #7ac37a;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row7_col6 {
#             background-color:  #98d498;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col0 {
#             background-color:  #6bbb6b;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col1 {
#             background-color:  #bfeabf;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col2 {
#             background-color:  #73c073;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col3 {
#             background-color:  #98d498;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col4 {
#             background-color:  #b1e2b1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col5 {
#             background-color:  #b8e6b8;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row8_col6 {
#             background-color:  #97d497;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col0 {
#             background-color:  #57b057;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col1 {
#             background-color:  #daf9da;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col2 {
#             background-color:  #52ad52;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col3 {
#             background-color:  #d1f4d1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col4 {
#             background-color:  #d5f6d5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col5 {
#             background-color:  #d5f6d5;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row9_col6 {
#             background-color:  #d1f4d1;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col0 {
#             background-color:  #6bbb6b;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col1 {
#             background-color:  #81c781;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col2 {
#             background-color:  #008000;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col3 {
#             background-color:  #9fd89f;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col4 {
#             background-color:  #72bf72;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col5 {
#             background-color:  #6fbd6f;
#         }    #T_717c622c_35dd_11e9_8ce7_1c4d707b05c5row10_col6 {
