# %% [markdown]
# # Introduction
#
# In this notebook we demonstrate the use of **LDA (Latent Dirichlet Allocation)** generative statistical model for Information Retrieval technique to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each test case content as an entire document that must be returned to the query made

# %% [markdown]
# # Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd
import numpy as np

from dit.divergences import jensen_shannon_divergence

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from modules.utils import plots
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import tokenizers as tok
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval

from modules.models.lda import LDA
from modules.models.model_hyperps import LDA_Model_Hyperp

from IPython.display import display

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Load Dataset

# %%
features_df = fd.read_features_df()
bug_reports_df = fd.read_bugreports_df()

corpus = features_df.feat_desc
query = bug_reports_df.br_desc

features_names = features_df.feat_name
bug_reports_names = bug_reports_df.br_name

orc = fd.read_feat_br_trace_df()
# Out:
# Features.shape: (21, 8)
# BugReports.shape: (93, 18)
# Feat_BR_Trace.shape: (21, 93)

# %% [markdown]
# # Running LDA Model
#
# In order to evaluate the efficiency of the algorithm tested (LSI), we use common metrics applied in the field of IR:
#
#     * Precision
#     * Recall
#     * F1-score

# %%
# %%time

lda_hyperp = {
    LDA_Model_Hyperp.TOP.value : 10,
    LDA_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : ('cosine',.75),
    LDA_Model_Hyperp.LDA_MODEL_N_COMPONENTS.value: 50,
    LDA_Model_Hyperp.LDA_MODEL_RANDOM_STATE.value : 2,
    LDA_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: (1,1),
    LDA_Model_Hyperp.VECTORIZER.value : TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True),
    LDA_Model_Hyperp.VECTORIZER_TOKENIZER.value : tok.PorterStemmerBased_Tokenizer() 
}

lda_model = LDA(**lda_hyperp)
lda_model.set_name('LDA_Model_AllData')
lda_model.recover_links(corpus, query, features_names, bug_reports_names)

print("\nModel Evaluation -------------------------------------------")
evaluator = m_eval.ModelEvaluator(orc, lda_model)
evaluator.evaluate_model(verbose=True)
# Out:
# Model Evaluation -------------------------------------------
# {'Measures': {'Mean FScore of LDA_Model_AllData': 0.05077658303464755,
#               'Mean Precision of LDA_Model_AllData': 0.028993855606758826,
#               'Mean Recall of LDA_Model_AllData': 0.20430107526881722},
#  'Setup': [{'Name': 'LDA_Model_AllData'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.75)},
#            {'Top Value': 10},
#            {'LDA Model': {'batch_size': 128,
#                           'doc_topic_prior': None,
#                           'evaluate_every': -1,
#                           'learning_decay': 0.7,
#                           'learning_method': 'batch',
#                           'learning_offset': 10.0,
#                           'max_doc_update_iter': 100,
#                           'max_iter': 10,
#                           'mean_change_tol': 0.001,
#                           'n_components': 50,
#                           'n_jobs': -1,
#                           'n_topics': None,
#                           'perp_tol': 0.1,
#                           'random_state': 2,
#                           'topic_word_prior': None,
#                           'total_samples': 1000000.0,
#                           'verbose': 0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <modules.utils.tokenizers.PorterStemmerBased_Tokenizer object at 0x7f6a3f176be0>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# CPU times: user 1.75 s, sys: 60.9 ms, total: 1.81 s
# Wall time: 1.67 s

# %%
aux_functions.highlight_df(orc.iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #008000;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4486_3acf_11e9_abad_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lda_model.get_trace_links_df().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #008000;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4487_3acf_11e9_abad_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lda_model.get_sim_matrix().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #5cb35c;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #078407;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #a6dca6;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #84c984;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #b8e6b8;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #3ea23e;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #9bd69b;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #afe1af;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #5ab25a;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #d4f6d4;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #83c983;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #68ba68;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #088408;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #058205;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #018001;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #098509;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #028102;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #038103;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #a6dca6;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #d4f6d4;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #cdf2cd;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #d6f7d6;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #bde9bd;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #d7f7d7;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #bbe8bb;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #178c17;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #4dab4d;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #2c982c;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #90d090;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #5bb25b;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #6abb6a;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #098509;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #058305;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #028102;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #098509;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #038103;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #048204;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e1fde1;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #b4e4b4;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #ccf1cc;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #c5edc5;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #cef2ce;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #b6e5b6;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #dcfadc;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #71bf71;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #b7e5b7;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #bee9be;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #9ed89e;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #d2f4d2;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #b8e6b8;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #4fac4f;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #69ba69;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #088408;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #058205;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #018001;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #098509;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #028102;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #038103;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #018001;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #a8dda8;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #87cb87;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #bbe8bb;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #42a442;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #9ed79e;
#         }    #T_e4ab4488_3acf_11e9_abad_1c4d707b05c5row10_col6 {
