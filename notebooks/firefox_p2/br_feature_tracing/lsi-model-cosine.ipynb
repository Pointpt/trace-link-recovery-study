# %% [markdown]
# # Introduction - Using COSINE Metric
#
# In this notebook we demonstrate the use of **LSI (Latent Semantic Indexing)** technique of Information Retrieval context to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each use case content as an entire document that must be returned to the query made

# %% [markdown]
# # Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from modules.utils import plots
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import tokenizers as tok
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval

from modules.models.lsi import LSI
from modules.models.model_hyperps import LSI_Model_Hyperp

import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from IPython.display import display

import warnings; warnings.simplefilter('ignore')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Load Dataset

# %%
features_df = fd.Datasets.read_features_df()
bug_reports_df = fd.Datasets.read_selected_bug_reports_2_df()

corpus = features_df.feat_desc
query = bug_reports_df.br_desc

features_names = features_df.feat_name
bug_reports_names = bug_reports_df.br_name

orc = fd.Feat_BR_Oracles.read_feat_br_expert_volunteers_df()
# Out:
# Features.shape: (21, 8)
# BugReports.shape: (93, 18)
# Feat_BR_Trace.shape: (21, 93)

# %% [markdown]
# # Running LSI Model
#
# In order to evaluate the efficiency of the algorithm tested (LSI), we use common metrics applied in the field of IR:
#
#     * Precision
#     * Recall
#     * F1-score

# %%
# %%time

lsi_hyperp = {
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : ('cosine' , .75),
    LSI_Model_Hyperp.TOP.value : 10,
    LSI_Model_Hyperp.SVD_MODEL_N_COMPONENTS.value: 100,
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: (1,1),
    LSI_Model_Hyperp.VECTORIZER.value : TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=False),
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : tok.WordNetBased_LemmaTokenizer()
}

lsi_model = LSI(**lsi_hyperp)
lsi_model.set_name('LSI_Model_AllData')
lsi_model.recover_links(corpus, query, features_names, bug_reports_names)

print("\nModel Evaluation -------------------------------------------")
evaluator = m_eval.ModelEvaluator(orc, lsi_model)
evaluator.evaluate_model(verbose=True)
# Out:
# Model Evaluation -------------------------------------------
# {'Measures': {'Mean FScore of LSI_Model_AllData': 0.06451612903225806,
#               'Mean Precision of LSI_Model_AllData': 0.06451612903225806,
#               'Mean Recall of LSI_Model_AllData': 0.06451612903225806},
#  'Setup': [{'Name': 'LSI_Model_AllData'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.75)},
#            {'Top Value': 10},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': False,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <modules.utils.tokenizers.WordNetBased_LemmaTokenizer object at 0x7f8e21480f98>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# CPU times: user 2.69 s, sys: 68.4 ms, total: 2.76 s
# Wall time: 1.69 s

# %%
aux_functions.highlight_df(orc.iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #008000;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af20_3acf_11e9_abad_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lsi_model.get_trace_links_df().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #008000;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af21_3acf_11e9_abad_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lsi_model.get_sim_matrix().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #45a645;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #9fd89f;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #008000;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #008000;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #abdfab;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #008000;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #269526;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #dbf9db;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #53ae53;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #b2e3b2;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #d8f8d8;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #97d497;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #a0d9a0;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #abdfab;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #d9f8d9;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #daf9da;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e1fde1;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #8ecf8e;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #a4dba4;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #e2fde2;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #91d091;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #d7f7d7;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #ccf1cc;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #168c16;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #daf9da;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e2fde2;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e1fde1;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e4fee4;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e4fee4;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #9ed89e;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e4fee4;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #c5edc5;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #43a543;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #50ac50;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #c8efc8;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #dcfadc;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #77c277;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #008000;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #bce8bc;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #79c379;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #a4dba4;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #b7e5b7;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #359d35;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #379e37;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #6dbc6d;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e3fee3;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #a6dca6;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #dcfadc;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #d5f6d5;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #41a441;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #1d901d;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #1c8f1c;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e2fde2;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #95d395;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #d8f8d8;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #cef2ce;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #1f911f;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #58b158;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #78c278;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #e3fee3;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #85ca85;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #dcfadc;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #d6f7d6;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #4fac4f;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #defbde;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #c0eac0;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e4fee4;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #bbe8bb;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #dcfadc;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #d7f7d7;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #55af55;
#         }    #T_b5d0af22_3acf_11e9_abad_1c4d707b05c5row10_col6 {
