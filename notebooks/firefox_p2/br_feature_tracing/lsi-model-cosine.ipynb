# %% [markdown]
# # Introduction - Using COSINE Metric
#
# In this notebook we demonstrate the use of **LSI (Latent Semantic Indexing)** technique of Information Retrieval context to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each use case content as an entire document that must be returned to the query made

# %% [markdown]
# ## Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from modules.utils import plots
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import tokenizers as tok
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval

from modules.models.lsi import LSI
from modules.models.model_hyperps import LSI_Model_Hyperp

import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from IPython.display import display

import warnings; warnings.simplefilter('ignore')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Load Dataset

# %%
features_df = fd.read_features_df()
bug_reports_df = fd.read_bugreports_df()

corpus = features_df.feat_desc
query = bug_reports_df.br_desc

features_names = features_df.feat_name
bug_reports_names = bug_reports_df.br_name

orc = fd.read_feat_br_trace_df()
# Out:
# Features.shape: (21, 8)
# BugReports.shape: (93, 19)
# Feat_BR_Trace.shape: (21, 93)

# %% [markdown]
# ## Evaluate Recovering Efficiency
#
# In order to evaluate the efficiency of the algorithm tested (LSI), we use common metrics applied in the field of IR:
#
#     * Precision
#     * Recall
#     * F1-score

# %% [markdown]
# ## Running LSI Model

# %%
# %%time

lsi_hyperp = {
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : ('cosine' , .75),
    LSI_Model_Hyperp.TOP.value : 10,
    LSI_Model_Hyperp.SVD_MODEL_N_COMPONENTS.value: 100,
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: (1,1),
    LSI_Model_Hyperp.VECTORIZER.value : TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=False),
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : tok.WordNetBased_LemmaTokenizer()
}

lsi_model = LSI(**lsi_hyperp)
lsi_model.set_name('LSI_Model_AllData')
lsi_model.recover_links(corpus, query, features_names, bug_reports_names)

print("\nModel Evaluation -------------------------------------------")
evaluator = m_eval.ModelEvaluator(orc, lsi_model)
evaluator.evaluate_model(verbose=True)
# Out:
# Model Evaluation -------------------------------------------
# {'Measures': {'Mean FScore of LSI_Model_AllData': 0.06451612903225806,
#               'Mean Precision of LSI_Model_AllData': 0.06451612903225806,
#               'Mean Recall of LSI_Model_AllData': 0.06451612903225806},
#  'Setup': [{'Name': 'LSI_Model_AllData'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.75)},
#            {'Top Value': 10},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': False,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <modules.utils.tokenizers.WordNetBased_LemmaTokenizer object at 0x7f85508d6588>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# CPU times: user 1.47 s, sys: 31.8 ms, total: 1.5 s
# Wall time: 445 ms

# %%
aux_functions.highlight_df(orc.iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #008000;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee634_3ab7_11e9_abad_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lsi_model.get_trace_links_df().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee635_3ab7_11e9_abad_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lsi_model.get_sim_matrix().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col0 {
#             background-color:  #86ca86;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col1 {
#             background-color:  #88cb88;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col2 {
#             background-color:  #67b967;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col3 {
#             background-color:  #008000;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col4 {
#             background-color:  #008000;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col5 {
#             background-color:  #a0d9a0;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row0_col6 {
#             background-color:  #1a8e1a;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col0 {
#             background-color:  #49a849;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col1 {
#             background-color:  #ccf1cc;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col2 {
#             background-color:  #5bb25b;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col3 {
#             background-color:  #96d396;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col4 {
#             background-color:  #9cd69c;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col5 {
#             background-color:  #9bd69b;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row1_col6 {
#             background-color:  #94d294;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col0 {
#             background-color:  #d8f8d8;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col3 {
#             background-color:  #cbf1cb;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col4 {
#             background-color:  #cbf1cb;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col5 {
#             background-color:  #d9f8d9;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row2_col6 {
#             background-color:  #80c780;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col0 {
#             background-color:  #50ac50;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col1 {
#             background-color:  #caf0ca;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col2 {
#             background-color:  #209220;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col3 {
#             background-color:  #97d497;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col4 {
#             background-color:  #56af56;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col5 {
#             background-color:  #0e880e;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row3_col6 {
#             background-color:  #b7e5b7;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col0 {
#             background-color:  #daf9da;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col1 {
#             background-color:  #ddfbdd;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col2 {
#             background-color:  #b0e2b0;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col3 {
#             background-color:  #cef2ce;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col4 {
#             background-color:  #cef2ce;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col5 {
#             background-color:  #76c176;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row4_col6 {
#             background-color:  #d8f8d8;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col0 {
#             background-color:  #ddfbdd;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col2 {
#             background-color:  #8cce8c;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col3 {
#             background-color:  #46a746;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col4 {
#             background-color:  #bde9bd;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row5_col6 {
#             background-color:  #5bb25b;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col0 {
#             background-color:  #008000;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col1 {
#             background-color:  #a4dba4;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col2 {
#             background-color:  #46a746;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col3 {
#             background-color:  #61b661;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col4 {
#             background-color:  #359d35;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col5 {
#             background-color:  #48a848;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row6_col6 {
#             background-color:  #3ea23e;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col0 {
#             background-color:  #67b967;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col1 {
#             background-color:  #d3f5d3;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col2 {
#             background-color:  #67b967;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col3 {
#             background-color:  #afe1af;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col4 {
#             background-color:  #8bcd8b;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col5 {
#             background-color:  #399f39;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row7_col6 {
#             background-color:  #008000;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col0 {
#             background-color:  #2a972a;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col1 {
#             background-color:  #cef2ce;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col2 {
#             background-color:  #3ea23e;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col3 {
#             background-color:  #a3daa3;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col4 {
#             background-color:  #6bbb6b;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col5 {
#             background-color:  #2e992e;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row8_col6 {
#             background-color:  #319b31;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col0 {
#             background-color:  #74c074;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col1 {
#             background-color:  #d4f6d4;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col2 {
#             background-color:  #4ba94b;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col3 {
#             background-color:  #b5e4b5;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col4 {
#             background-color:  #94d294;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col5 {
#             background-color:  #4aa94a;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row9_col6 {
#             background-color:  #c9efc9;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col0 {
#             background-color:  #98d498;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col1 {
#             background-color:  #d4f6d4;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col2 {
#             background-color:  #67b967;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col3 {
#             background-color:  #b5e4b5;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col4 {
#             background-color:  #94d294;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col5 {
#             background-color:  #4aa94a;
#         }    #T_bb7ee636_3ab7_11e9_abad_1c4d707b05c5row10_col6 {
