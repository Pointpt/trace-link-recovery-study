# %% [markdown]
# # Introduction - Using COSINE Metric
#
# In this notebook we demonstrate the use of **LSI (Latent Semantic Indexing)** technique of Information Retrieval context to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each use case content as an entire document that must be returned to the query made

# %% [markdown]
# ## Import Libraries

# %%
import sys
if '../..' not in sys.path:
    sys.path.append('../..')

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from modules.utils import plots
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import tokenizers as tok
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval

from modules.models.lsi import LSI
from modules.models.model_hyperps import LSI_Model_Hyperp

import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from IPython.display import display

import warnings; warnings.simplefilter('ignore')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Load Dataset

# %%
test_cases_df = fd.read_testcases_df()
bug_reports_df = fd.read_bugreports_df()

corpus = test_cases_df.tc_desc
query = bug_reports_df.br_desc

test_cases_names = test_cases_df.tc_name
bug_reports_names = bug_reports_df.br_name

orc = fd.read_trace_df()
# Out:
# TestCases.shape: (207, 12)
# BugReports.shape: (93, 19)
# Oracle.shape: (207, 93)

# %% [markdown]
# ## Evaluate Recovering Efficiency
#
# In order to evaluate the efficiency of the algorithm tested (LSI), we use common metrics applied in the field of IR:
#
#     * Precision
#     * Recall
#     * F1-score

# %% [markdown]
# ## Running LSI Model

# %%
# %%time

lsi_hyperp = {
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : ('cosine' , .80),
    LSI_Model_Hyperp.TOP.value : 10,
    LSI_Model_Hyperp.SVD_MODEL_N_COMPONENTS.value: 100,
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: (1,1),
    LSI_Model_Hyperp.VECTORIZER.value : TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True),
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : tok.WordNetBased_LemmaTokenizer()
}

lsi_model = LSI(**lsi_hyperp)
lsi_model.set_name('LSI_Model_AllData')
lsi_model.recover_links(corpus, query, test_cases_names, bug_reports_names)

print("\nModel Evaluation -------------------------------------------")
evaluator = m_eval.ModelEvaluator(orc, lsi_model)
evaluator.evaluate_model(verbose=True)
# Out:
# Model Evaluation -------------------------------------------
# {'Measures': {'Mean FScore of LSI_Model_AllData': 0.0030721966205837174,
#               'Mean Precision of LSI_Model_AllData': 0.010752688172043012,
#               'Mean Recall of LSI_Model_AllData': 0.0017921146953405018},
#  'Setup': [{'Name': 'LSI_Model_AllData'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.8)},
#            {'Top Value': 100},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.WordNetBased_LemmaTokenizer object at 0x7f25531e92b0>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# CPU times: user 3.31 s, sys: 69.2 ms, total: 3.38 s
# Wall time: 2.2 s

# %%
aux_functions.highlight_df(orc.iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2a_35dd_11e9_8ce7_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lsi_model.get_trace_links_df().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row6_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row9_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2b_35dd_11e9_8ce7_1c4d707b05c5row10_col6 {

# %%
aux_functions.highlight_df(lsi_model.get_sim_matrix().iloc[0:20, 0:7])
# Out:
# <style  type="text/css" >
#     #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col0 {
#             background-color:  #88cb88;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col1 {
#             background-color:  #d0f3d0;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col2 {
#             background-color:  #98d498;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col3 {
#             background-color:  #defbde;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col4 {
#             background-color:  #a4dba4;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col5 {
#             background-color:  #0e870e;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row0_col6 {
#             background-color:  #a8dda8;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col0 {
#             background-color:  #80c780;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col1 {
#             background-color:  #bce8bc;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col2 {
#             background-color:  #bde9bd;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col3 {
#             background-color:  #bce8bc;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col4 {
#             background-color:  #89cc89;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col5 {
#             background-color:  #59b159;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row1_col6 {
#             background-color:  #c8efc8;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col0 {
#             background-color:  #6ebd6e;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col1 {
#             background-color:  #cef2ce;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col2 {
#             background-color:  #cef2ce;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col3 {
#             background-color:  #e1fde1;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col4 {
#             background-color:  #a1d9a1;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col5 {
#             background-color:  #46a746;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row2_col6 {
#             background-color:  #e3fee3;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col0 {
#             background-color:  #8fcf8f;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col1 {
#             background-color:  #c4edc4;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col2 {
#             background-color:  #cdf2cd;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col4 {
#             background-color:  #67b967;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col5 {
#             background-color:  #5cb35c;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col0 {
#             background-color:  #56af56;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col1 {
#             background-color:  #c7eec7;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col2 {
#             background-color:  #b8e6b8;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col3 {
#             background-color:  #e2fde2;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col4 {
#             background-color:  #bee9be;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col5 {
#             background-color:  #018001;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row4_col6 {
#             background-color:  #c8efc8;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col0 {
#             background-color:  #78c278;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col1 {
#             background-color:  #8acc8a;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col2 {
#             background-color:  #309a30;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col3 {
#             background-color:  #a8dda8;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col4 {
#             background-color:  #74c074;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col5 {
#             background-color:  #2a972a;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row5_col6 {
#             background-color:  #bde9bd;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col0 {
#             background-color:  #b5e4b5;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col1 {
#             background-color:  #92d192;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col2 {
#             background-color:  #008000;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col3 {
#             background-color:  #73c073;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col4 {
#             background-color:  #aadeaa;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col5 {
#             background-color:  #91d091;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row6_col6 {
#             background-color:  #caf0ca;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col0 {
#             background-color:  #058205;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col1 {
#             background-color:  #b0e2b0;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col2 {
#             background-color:  #47a747;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col3 {
#             background-color:  #b1e2b1;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col4 {
#             background-color:  #91d091;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col5 {
#             background-color:  #319b31;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row7_col6 {
#             background-color:  #bfeabf;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col0 {
#             background-color:  #008000;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col1 {
#             background-color:  #c5edc5;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col2 {
#             background-color:  #4fac4f;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col3 {
#             background-color:  #a2daa2;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col4 {
#             background-color:  #a0d9a0;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col5 {
#             background-color:  #57b057;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row8_col6 {
#             background-color:  #c1ebc1;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col0 {
#             background-color:  #cbf1cb;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col1 {
#             background-color:  #c7eec7;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col2 {
#             background-color:  #85ca85;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col3 {
#             background-color:  #d3f5d3;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col4 {
#             background-color:  #d2f4d2;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col5 {
#             background-color:  #7ec67e;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row9_col6 {
#             background-color:  #d2f4d2;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col0 {
#             background-color:  #289628;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col1 {
#             background-color:  #bce8bc;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col2 {
#             background-color:  #48a848;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col3 {
#             background-color:  #d1f4d1;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col4 {
#             background-color:  #9dd79d;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col5 {
#             background-color:  #44a544;
#         }    #T_3c690a2c_35dd_11e9_8ce7_1c4d707b05c5row10_col6 {
