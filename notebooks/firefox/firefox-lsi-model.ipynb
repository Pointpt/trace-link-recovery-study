# %% [markdown]
# # Introduction
#
# In this notebook we demonstrate the use of **LSI (Latent Semantic Indexing)** technique of Information Retrieval context to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each use case content as an entire document that must be returned to the query made

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_recall_fscore_support, pairwise_distances, pairwise
from sklearn.externals.joblib import Parallel, delayed
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import Normalizer, normalize

from enum import Enum
import pickle
import nltk

from utils import plots
from utils import firefox_dataset as fd
from utils import tokenizers as tok
from utils import aux_functions
from utils import model_evaluator as m_eval
from utils import generic_model as g_model

import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import warnings; warnings.simplefilter('ignore')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Load Dataset and Preprocessing

# %%
test_cases_df = fd.read_testcases_df()
bug_reports_df = fd.read_bugreports_df()

corpus = test_cases_df.tc_desc
query = bug_reports_df.br_desc

test_cases_names = test_cases_df.tc_name
bug_reports_names = bug_reports_df.br_name

orc = fd.read_trace_df()
orc.set_index('tc_name', inplace=True, drop=True)

# %%
print(bug_reports_df.shape)
bug_reports_df.head()
# Out:
# (35314, 12)
#    Bug_Number                                            Summary Platform  \
# 0      506297  Livemarks with null site/feed uris cause sync ...      All
# 1      506338     Enhance Crash Recovery to better help the user      All
# 2      506507  Dragging multiple bookmarks in the bookmarks s...      x86
# 3      506550      Unreliable Back Button navigating nytimes.com      x86
# 4      506575  ALT + F4 when dropdown of autocomplete is open...      x86
#
#                  Component      Version         Creation_Time  \
# 0                     Sync  unspecified  2009-07-24T17:08:43Z
# 1          Session Restore        Trunk  2009-07-24T19:17:21Z
# 2      Bookmarks & History        Trunk  2009-07-26T06:16:02Z
# 3  Extension Compatibility   3.5 Branch  2009-07-26T16:12:10Z
# 4              Address Bar   3.5 Branch  2009-07-26T20:14:54Z
#
#                                        Whiteboard QA_Whiteboard  \
# 0                                             NaN           NaN
# 1                  [crashkill][crashkill-metrics]           NaN
# 2                                             NaN           NaN
# 3  [caused by adblock plus][platform-rel-NYTimes]           NaN
# 4                                             NaN           NaN
#
#                                   First_Comment_Text  \
# 0  2009-07-24 09:54:28     FaultTolerance       D...
# 1  When our users crash they are pretty much in t...
# 2  User-Agent:       Mozilla/5.0 (Windows; U; Win...
# 3  User-Agent:       Mozilla/5.0 (Windows; U; Win...
# 4  Pressing ALT + F4 when the autocomplete dropdo...
#
#   First_Comment_Creation_Time        br_name  \
# 0        2009-07-24T17:08:43Z  BR_506297_SRC
# 1        2009-07-24T19:17:21Z  BR_506338_SRC
# 2        2009-07-26T06:16:02Z  BR_506507_SRC
# 3        2009-07-26T16:12:10Z  BR_506550_SRC
# 4        2009-07-26T20:14:54Z  BR_506575_SRC
#
#                                              br_desc
# 0  506297 Livemarks with null site/feed uris caus...
# 1  506338 Enhance Crash Recovery to better help t...
# 2  506507 Dragging multiple bookmarks in the book...
# 3  506550 Unreliable Back Button navigating nytim...
# 4  506575 ALT + F4 when dropdown of autocomplete ...

# %%
print(test_cases_df.shape)
test_cases_df.head()
# Out:
# (207, 10)
#    TC_Number   TestDay                                          Gen_Title  \
# 0          1  20181221  <notificationbox> \nand\n <notification>\n cha...
# 1          2  20181221  <notificationbox> \nand\n <notification>\n cha...
# 2          3  20181221  <notificationbox> \nand\n <notification>\n cha...
# 3          4  20181221  <notificationbox> \nand\n <notification>\n cha...
# 4          5  20181221  <notificationbox> \nand\n <notification>\n cha...
#
#    Crt_Nr                                              Title Preconditions  \
# 0       1                         Notification - Popup Block           NaN
# 1       2                        Notification - Process Hang           NaN
# 2       3            Verify Notifications appear in RTL Mode           NaN
# 3       4  Verify Notifications appear in High Contrast M...           NaN
# 4       5  Verify notifications react to differing Zoom l...           NaN
#
#                                                Steps  \
# 0  1. Launch Firefox\n2. Navigate to http://www.p...
# 1  1. Launch Firefox\n2. In the URL bar, navigate...
# 2  1. Launch Firefox\n2. In about:config, change ...
# 3  1. While the browser is in High Contrast Mode,...
# 4  1. While the browser is in High Contrast Mode,...
#
#                                      Expected_Result   tc_name  \
# 0  1. Firefox is successfully launched\n9. The al...  TC_1_TRG
# 1  1. Firefox is successfully launched\n2. Firefo...  TC_2_TRG
# 2  1. Firefox is successfully launched\n2.The for...  TC_3_TRG
# 3  1. Firefox has been launched.\n2. Firefox begi...  TC_4_TRG
# 4  1. Firefox has been launched.\n2. Firefox begi...  TC_5_TRG
#
#                                              tc_desc
# 0  1 20181221 <notificationbox> \nand\n <notifica...
# 1  2 20181221 <notificationbox> \nand\n <notifica...
# 2  3 20181221 <notificationbox> \nand\n <notifica...
# 3  4 20181221 <notificationbox> \nand\n <notifica...
# 4  5 20181221 <notificationbox> \nand\n <notifica...

# %%
print(orc.shape)
orc.head()
# Out:
# (207, 35314)
#           BR_506297_SRC  BR_506338_SRC  BR_506507_SRC  BR_506550_SRC  \
# tc_name
# TC_1_TRG              0              0              0              0
# TC_2_TRG              0              0              0              0
# TC_3_TRG              0              0              0              0
# TC_4_TRG              0              0              0              0
# TC_5_TRG              0              0              0              0
#
#           BR_506575_SRC  BR_506729_SRC  BR_506768_SRC  BR_506795_SRC  \
# tc_name
# TC_1_TRG              0              0              0              0
# TC_2_TRG              0              0              0              0
# TC_3_TRG              0              0              0              0
# TC_4_TRG              0              0              0              0
# TC_5_TRG              0              0              0              0
#
#           BR_506820_SRC  BR_506831_SRC       ...        BR_1516270_SRC  \
# tc_name                                      ...
# TC_1_TRG              0              0       ...                     0
# TC_2_TRG              0              0       ...                     0
# TC_3_TRG              0              0       ...                     0
# TC_4_TRG              0              0       ...                     0
# TC_5_TRG              0              0       ...                     0
#
#           BR_1516329_SRC  BR_1516358_SRC  BR_1516416_SRC  BR_1516505_SRC  \
# tc_name
# TC_1_TRG               0               0               0               0
# TC_2_TRG               0               0               0               0
# TC_3_TRG               0               0               0               0
# TC_4_TRG               0               0               0               0
# TC_5_TRG               0               0               0               0
#
#           BR_1516547_SRC  BR_1516582_SRC  BR_1516749_SRC  BR_1516792_SRC  \
# tc_name
# TC_1_TRG               0               0               0               0
# TC_2_TRG               0               0               0               0
# TC_3_TRG               0               0               0               0
# TC_4_TRG               0               0               0               0
# TC_5_TRG               0               0               0               0
#
#           BR_1516895_SRC
# tc_name
# TC_1_TRG               0
# TC_2_TRG               0
# TC_3_TRG               0
# TC_4_TRG               0
# TC_5_TRG               0
#
# [5 rows x 35314 columns]

# %% [markdown]
# # LSI Model

# %% [markdown]
# #### Model Hyperparameters

# %%
class LSI_Model_Hyperp(Enum):
    NAME = 'lsi__name'
    TOP = 'lsi__top'
    SIM_MEASURE_MIN_THRESHOLD = 'lsi__sim_measure_min_threshold'
    VECTORIZER = 'lsi__vectorizer'
    VECTORIZER_STOP_WORDS = 'lsi__vectorizer__stop_words'
    VECTORIZER_TOKENIZER = 'lsi__vectorizer__tokenizer'
    VECTORIZER_USE_IDF = 'lsi__vectorizer__use_idf'
    VECTORIZER_SMOOTH_IDF = 'lsi__vectorizer__smooth_idf'
    VECTORIZER_NGRAM_RANGE = 'lsi__vectorizer__ngram_range'
    SVD_MODEL = 'lsi__svd_model'
    SVD_MODEL_N_COMPONENTS = 'lsi__svd_model__n_components'

# %% [markdown]
# #### Distance Functions / Similarity Measures Available

# %%
class SimilarityMeasure(Enum):
    COSINE = 'cosine'
    JACCARD_INDEX = 'jaccard'
    EDIT_DISTANCE = 'edit'

# %% [markdown]
# #### Model Definition

# %%
"""
params_dict = {
    'lsi__sim_measure_min_threshold' : ('cosine',.9),
    'lsi__name' : 'LSI',
    'lsi__top' : 3,
    'lsi__vectorizer' : TfidfVectorizer(),
    'lsi__vectorizer__stop_words' : 'english',
    'lsi__vectorizer__tokenizer' : Tokenizer(),
    'lsi__vectorizer__use_idf' : True,          # optional if type(Vectorizer) == TfidfVectorizer
    'lsi__vectorizer__smooth_idf' : True,       # optional if type(Vectorizer) == TfidfVectorizer
    'lsi__vectorizer__ngram_range' : (1,2),
    'lsi__svd_model' : TruncatedSVD(),
    'lsi__svd_model__n_components' : 5
}
"""
class LSI(g_model.GenericModel):
    def __init__(self, **kwargs):
        self._svd_matrix = None
        self._query_vector = None
        
        self.vectorizer = None
        self.svd_model = None
        
        super().__init__()
        
        self.set_basic_params(**kwargs)
        self.set_vectorizer(**kwargs)
        self.set_svd_model(**kwargs)
    
    def set_name(self, name):
        super().set_name(name)
    
    def set_model_gen_name(self, gen_name):
        super().set_model_gen_name(gen_name)
    
    def set_top(self, top):
        super().set_top(top)
    
    def set_sim_measure_min_threshold(self, threshold):
        super().set_sim_measure_min_threshold(threshold)
    
    def set_basic_params(self, **kwargs):
        self.set_name('LSI' if LSI_Model_Hyperp.NAME.value not in kwargs.keys() else kwargs[LSI_Model_Hyperp.NAME.value])
        self.set_sim_measure_min_threshold((SimilarityMeasure.COSINE.value,.80) if LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value not in kwargs.keys() else kwargs[LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value])
        self.set_top(3 if LSI_Model_Hyperp.TOP.value not in kwargs.keys() else kwargs[LSI_Model_Hyperp.TOP.value])
        self.set_model_gen_name('lsi')
    
    def set_vectorizer(self, **kwargs):
        self.vectorizer = TfidfVectorizer(stop_words='english',
                                             use_idf=True, 
                                             smooth_idf=True) if LSI_Model_Hyperp.VECTORIZER.value not in kwargs.keys() else kwargs[LSI_Model_Hyperp.VECTORIZER.value]
        
        vec_params = {key.split('__')[2]:kwargs[key] for key,val in kwargs.items() if '__vectorizer__' in key}
        self.vectorizer.set_params(**vec_params)
    
    def set_svd_model(self, **kwargs):
        self.svd_model = TruncatedSVD(n_components = 100, 
                                         algorithm = 'randomized',
                                         n_iter = 10, 
                                         random_state = 42) if LSI_Model_Hyperp.SVD_MODEL.value not in kwargs.keys() else kwargs[LSI_Model_Hyperp.SVD_MODEL.value]
        
        svd_model_params = {key.split('__')[2]:kwargs[key] for key,val in kwargs.items() if '__svd_model__' in key}
        self.svd_model.set_params(**svd_model_params)
        
    
    def recover_links(self, corpus, query, test_cases_names, bug_reports_names):
        metric = self.sim_measure_min_threshold[0]
        
        if metric == SimilarityMeasure.COSINE.value:
            return self._recover_links_cosine(corpus, query, test_cases_names, bug_reports_names)
        
        elif metric == SimilarityMeasure.JACCARD_INDEX.value:
            return self._recover_links_jaccard(corpus, query, test_cases_names, bug_reports_names)
        
        elif metric == SimilarityMeasure.EDIT_DISTANCE.value:
            return self._recover_links_edit(corpus, query, test_cases_names, bug_reports_names)
    
    def _recover_links_cosine(self, corpus, query, test_cases_names, bug_reports_names):
        svd_transformer = Pipeline([('vec', self.vectorizer), 
                            ('svd', self.svd_model)])

        self._svd_matrix = svd_transformer.fit_transform(corpus)
        self._query_vector = svd_transformer.transform(query)
        self._sim_matrix = pairwise.cosine_similarity(X=self._svd_matrix, Y=self._query_vector)
        self._sim_matrix = pd.DataFrame(data=self._sim_matrix, index=test_cases_names, columns=bug_reports_names)
        
        super()._fillUp_traceLinksDf(test_cases_names, bug_reports_names, self._sim_matrix) 
    
    def _recover_links_jaccard(self, corpus, query, test_cases_names, bug_reports_names):
        tokenizer = self.vectorizer.tokenizer
                
        corpus_tokens = [tokenizer.__call__(doc) for doc in corpus]        
        query_tokens = [tokenizer.__call__(doc) for doc in query]
        
        self._sim_matrix = pd.DataFrame(index = test_cases_names, 
                                       columns = bug_reports_names,
                                       data = np.zeros(shape=(len(test_cases_names), len(bug_reports_names)), dtype='int8'))
        
        for br_id, doc_query_tset in zip(bug_reports_names, query_tokens):
            for tc_id, doc_corpus_tset in zip(test_cases_names, corpus_tokens):
                self._sim_matrix.at[tc_id, br_id] = nltk.jaccard_distance(set(doc_corpus_tset), set(doc_query_tset))
        
        super()._fillUp_traceLinksDf(test_cases_names, bug_reports_names, self._sim_matrix) 
    
    def _recover_links_edit(self, corpus, query, test_cases_names, bug_reports_names):
        self._sim_matrix = pd.DataFrame(index = test_cases_names, 
                                       columns = bug_reports_names,
                                       data = np.zeros(shape=(len(test_cases_names), len(bug_reports_names)), dtype='int8'))
                
        for br_id, doc_query in zip(bug_reports_names, query):
            for tc_id, doc_corpus in zip(test_cases_names, corpus):
                self._sim_matrix.at[tc_id, br_id] = nltk.edit_distance(doc_corpus, doc_query)
        
        normalizer = Normalizer(copy=False).fit(self._sim_matrix.values)
        self._sim_matrix = pd.DataFrame(data=normalizer.transform(self._sim_matrix.values), index=test_cases_names, columns=bug_reports_names)
        
        super()._fillUp_traceLinksDf(test_cases_names, bug_reports_names, self._sim_matrix)
    
    def model_setup(self):
        return {"Setup" : 
                  [
                      {"Name" : self.get_name()},
                      {"Similarity Measure and Minimum Threshold" : self.get_sim_measure_min_threshold()},
                      {"Top Value" : self.get_top_value()},
                      {"SVD Model" : self.svd_model.get_params()},
                      {"Vectorizer" : self.vectorizer.get_params()},
                      {"Vectorizer Type" : type(self.vectorizer)}
                  ]
               }
        
    def get_query_vector(self):
        return self._query_vector
    
    def get_svd_matrix(self):
        return self._svd_matrix
    
    def get_vectorizer_type(self):
        return type(self.vectorizer)
    
    def get_tokenizer_type(self):
        return type(self.vectorizer.tokenizer)    
        
    def get_name(self):
        return super().get_name()

    def get_model_gen_name(self):
        return super().get_model_gen_name()
    
    def get_top_value(self):
        return super().get_top_value()
    
    def get_sim_measure_min_threshold(self):
        return super().get_sim_measure_min_threshold()
    
    def get_sim_matrix(self):
        return super().get_sim_matrix()
        
    def get_trace_links_df(self):
        return super().get_trace_links_df()
    
    def save_sim_matrix(self):
        super().save_sim_matrix()
    
    def get_model_dump_path(self):
        return super().get_model_dump_path()

# %% [markdown]
# ## Evaluate Recovering Efficiency
#
# In order to evaluate the efficiency of the algorithm tested (LSI), we use common metrics applied in the field of IR:
#
#     * Precision
#     * Recall
#     * F1-score

# %% [markdown]
# ### Analysis with Default Values of LSI Model

# %%
# %%time

best_model = LSI()
best_model.recover_links(corpus, query, test_cases_names, bug_reports_names)
# Out:
# CPU times: user 1h 8min 24s, sys: 19min 5s, total: 1h 27min 30s
# Wall time: 21min 56s

# %%
best_model.get_trace_links_df().shape
# Out:
# (207, 35314)

# %%
# %%time

evaluator = m_eval.ModelEvaluator(orc, best_model)
evaluator.evaluate_model(verbose=True)
#evaluator.plot_precision_vs_recall()
# Out:
# {'Measures': {'Mean FScore of LSI': 3.7433692894004805e-05,
#               'Mean Precision of LSI': 0.0007456910384927602,
#               'Mean Recall of LSI': 1.9314480139230012e-05},
#  'Setup': [{'Name': 'LSI'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.8)},
#            {'Top Value': 3},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': None,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}

# %% [markdown]
# ### Quick Test Jaccard Values

# %%
all_hyperparams = {
    LSI_Model_Hyperp.TOP.value : [5],
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: [(1,1)],
    LSI_Model_Hyperp.VECTORIZER.value : [TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)],
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : [tok.PorterStemmerBased_Tokenizer()],
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : [('jaccard',x) for x in [.2]],
}

hyperparams = aux_functions.generate_params_comb_list(**all_hyperparams)

print('Performing model hyperparameters search...')

def run_model(idx, **hyperp):    
    current_model = LSI(**hyperp)
    current_model.set_name('LSI_Model_{}'.format(idx))
    current_model.recover_links(corpus, query, use_cases_names, bug_reports_names)
    
    evaluator = m_eval.ModelEvaluator(orc.oracle, current_model)
    evaluator.evaluate_model()
    evaluator.dump_model()
    evaluator.dump_evaluator()
    
    return([evaluator.get_mean_precision(), 
            evaluator.get_mean_recall(),
            evaluator.get_mean_fscore(), 
            evaluator.get_model().get_name(),
            evaluator.get_model().get_top_value(),
            evaluator.get_model().get_vectorizer_type(), 
            evaluator.get_model().get_tokenizer_type(),
            evaluator.get_model().get_sim_measure_min_threshold()[0],
            evaluator.get_model().get_sim_measure_min_threshold()[1],
            evaluator.get_model().get_model_dump_path(),
            evaluator.get_evaluator_dump_path()
           ])

tasks = [(idx,hp) for idx,hp in enumerate(hyperparams)]
results = Parallel(n_jobs=-1, verbose=1)(delayed(run_model)(idx, **hp) for idx,hp in tasks)
results_df = pd.DataFrame(data=results, 
                          columns=['precision', 'recall', 'fscore', 'model_name', 'top_value', 'vectorizer', 'tokenizer', 'metric', 'metric_value', 'model_dump', 'evaluator_dump'])
results_df = results_df.astype(dtype={'model_dump' : str, 'evaluator_dump' : str})
# Out:
# Performing model hyperparameters search...
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.1s finished

# %% [markdown]
# #### Evaluate

# %%
best_model = aux_functions.report_best_model(results_df)
# Out:
# ------------ Report -------------------
#
# Total of Analyzed Hyperparameters Combinations: 1
#
# Best Model Hyperparameters Combination Found:
#
# {'Measures': {'Mean FScore of LSI_Model_0': 0.0,
#               'Mean Precision of LSI_Model_0': 0.0,
#               'Mean Recall of LSI_Model_0': 0.0},
#  'Setup': [{'Name': 'LSI_Model_0'},
#            {'Similarity Measure and Minimum Threshold': ('jaccard', 0.2)},
#            {'Top Value': 5},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.int64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.PorterStemmerBased_Tokenizer object at 0x7fef7d73b080>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}

# %%
best_model.get_sim_matrix()
# Out:
# artf_name   BR_4020_SRC  BR_3890_SRC  BR_3844_SRC  BR_4065_SRC  BR_3880_SRC  \
# artf_name
# UC_003_TRG            0            0            0            0            0
# UC_007_TRG            0            0            0            0            0
# UC_010_TRG            0            0            0            0            0
# UC_002_TRG            0            0            0            0            0
# UC_006_TRG            0            0            0            0            0
# UC_004_TRG            0            0            0            0            0
# UC_005_TRG            0            0            0            0            0
# UC_008_TRG            0            0            0            0            0
# UC_001_TRG            0            0            0            0            0
# UC_009_TRG            0            0            0            0            0
#
# artf_name   BR_3987_SRC  BR_4067_SRC  BR_3973_SRC  BR_3898_SRC  BR_3908_SRC  \
# artf_name
# UC_003_TRG            0            0            0            0            0
# UC_007_TRG            0            0            0            0            0
# UC_010_TRG            0            0            0            0            0
# UC_002_TRG            0            0            0            0            0
# UC_006_TRG            0            0            0            0            0
# UC_004_TRG            0            0            0            0            0
# UC_005_TRG            0            0            0            0            0
# UC_008_TRG            0            0            0            0            0
# UC_001_TRG            0            0            0            0            0
# UC_009_TRG            0            0            0            0            0
#
# artf_name   BR_4058_SRC  BR_4018_SRC  BR_4005_SRC  BR_3974_SRC
# artf_name
# UC_003_TRG            0            0            0            0
# UC_007_TRG            0            0            0            0
# UC_010_TRG            0            0            0            0
# UC_002_TRG            0            0            0            0
# UC_006_TRG            0            0            0            0
# UC_004_TRG            0            0            0            0
# UC_005_TRG            0            0            0            0
# UC_008_TRG            0            0            0            0
# UC_001_TRG            0            0            0            0
# UC_009_TRG            0            0            0            0

# %% [markdown]
# ### Quick Test Edit Values

# %%
all_hyperparams = {
    LSI_Model_Hyperp.TOP.value : [5],
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: [(1,1)],
    LSI_Model_Hyperp.VECTORIZER.value : [TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)],
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : [tok.PorterStemmerBased_Tokenizer()],
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : [('edit',x) for x in [.3]],
}

hyperparams = aux_functions.generate_params_comb_list(**all_hyperparams)

print('Performing model hyperparameters search...')

def run_model(idx, **hyperp):    
    current_model = LSI(**hyperp)
    current_model.set_name('LSI_Model_{}'.format(idx))
    current_model.recover_links(corpus, query, use_cases_names, bug_reports_names)
    
    evaluator = m_eval.ModelEvaluator(orc.oracle, current_model)
    evaluator.evaluate_model()
    evaluator.dump_model()
    evaluator.dump_evaluator()
    
    return([evaluator.get_mean_precision(), 
            evaluator.get_mean_recall(),
            evaluator.get_mean_fscore(), 
            evaluator.get_model().get_name(),
            evaluator.get_model().get_top_value(),
            evaluator.get_model().get_vectorizer_type(), 
            evaluator.get_model().get_tokenizer_type(),
            evaluator.get_model().get_sim_measure_min_threshold()[0],
            evaluator.get_model().get_sim_measure_min_threshold()[1],
            evaluator.get_model().get_model_dump_path(),
            evaluator.get_evaluator_dump_path()
           ])

#tasks = [(idx,hp) for idx,hp in enumerate(hyperparams)]
#results = Parallel(n_jobs=-1, verbose=1)(delayed(run_model)(idx, **hp) for idx,hp in tasks)
#results_df = pd.DataFrame(data=results, 
#                          columns=['precision', 'recall', 'fscore', 'model_name', 'top_value', 'vectorizer', 'tokenizer', 'metric', 'metric_value', 'model_dump', 'evaluator_dump'])
#results_df = results_df.astype(dtype={'model_dump' : str, 'evaluator_dump' : str})
# Out:
# Performing model hyperparameters search...

# %% [markdown]
# #### Evaluate

# %%
#best_model = aux_functions.report_best_model(results_df)

# %%
#best_model.get_sim_matrix()

# %%
#aux_functions.highlight_df(best_model.get_trace_links_df())

# %% [markdown]
# ### Try Specific Model - Estimated Best Hyperparameters

# %% [markdown]
# ##### Get Dataset Subsets

# %%
bugreports_subset_df = bug_reports_df[(bug_reports_df.Version == '48 Branch') | (bug_reports_df.Version == '60 Branch')].sample(15, random_state=42)
testcases_subset_df = test_cases_df[(test_cases_df.TestDay.str.contains('20161014')) | (test_cases_df.TestDay.str.contains('20161028'))].sample(10, random_state=1000)

selected_testcases = ['TC_{}_TRG'.format(tc_num) for tc_num in [13, 14, 15, 16, 17, 18]]  # should link with 48 Branch
aux_tc = test_cases_df[test_cases_df.tc_name.isin(selected_testcases)]

tc_subset_df = testcases_subset_df.append(aux_tc)
tc_subset_df.drop_duplicates(inplace=True)

corpus_subset = tc_subset_df.tc_desc
query_subset = bugreports_subset_df.br_desc
testcases_names_subset = tc_subset_df.tc_name
bug_reports_names_subset = bugreports_subset_df.br_name
orc_subset_df = orc.loc[testcases_names_subset, bug_reports_names_subset]

print('TestCases Subset Shape: {}'.format(tc_subset_df.shape))
print('BugReports Subset Shape: {}'.format(bugreports_subset_df.shape))
print('Oracle Subset Shape: {}'.format(orc_subset_df.shape))
# Out:
# TestCases Subset Shape: (14, 10)
# BugReports Subset Shape: (15, 12)
# Oracle Subset Shape: (14, 15)

# %% [markdown]
# #### Checking Content of Bugs

# %%
bugreports_subset_df[bugreports_subset_df.Version == '48 Branch'].head()
# Out:
#        Bug_Number                                            Summary  \
# 11303     1268934        Reducing tab height causes a gap above tabs
# 12186     1282551  CTRL+G finds text hidden in a drop down menu, ...
# 12729     1291175                   revert new "awesome" bar in FF48
# 13465     1299787  Impossible to set browser.urlbar.maxRichResult...
#
#           Platform  Component    Version         Creation_Time Whiteboard  \
# 11303  Unspecified      Theme  48 Branch  2016-04-29T17:43:31Z        NaN
# 12186  Unspecified     Search  48 Branch  2016-06-27T19:30:07Z        NaN
# 12729  Unspecified  Untriaged  48 Branch  2016-08-02T05:52:12Z        NaN
# 13465  Unspecified  Untriaged  48 Branch  2016-09-01T12:49:52Z        NaN
#
#       QA_Whiteboard                                 First_Comment_Text  \
# 11303           NaN  Created attachment 8747147 output.webm  User A...
# 12186           NaN  User Agent: Mozilla/5.0 (X11; Linux i686; rv:4...
# 12729           NaN  User Agent: Mozilla/5.0 (Windows NT 6.1; Win64...
# 13465           NaN  User Agent: Mozilla/5.0 (X11; Ubuntu; Linux i6...
#
#       First_Comment_Creation_Time         br_name  \
# 11303        2016-04-29T17:43:31Z  BR_1268934_SRC
# 12186        2016-06-27T19:30:07Z  BR_1282551_SRC
# 12729        2016-08-02T05:52:12Z  BR_1291175_SRC
# 13465        2016-09-01T12:49:52Z  BR_1299787_SRC
#
#                                                  br_desc
# 11303  1268934 Reducing tab height causes a gap above...
# 12186  1282551 CTRL+G finds text hidden in a drop dow...
# 12729  1291175 revert new "awesome" bar in FF48 Unspe...
# 13465  1299787 Impossible to set browser.urlbar.maxRi...

# %%
testcases_subset_df[testcases_subset_df.TestDay.str.contains('20160603')].head()
# Out:
#     TC_Number                         TestDay  \
# 18         19  20160603 + 20160624 + 20161014
# 15         16  20160603 + 20160624 + 20161014
# 14         15  20160603 + 20160624 + 20161014
#
#                                         Gen_Title  Crt_Nr  \
# 18  new awesomebar tests - awesome bar icons left       7
# 15      new awesomebar tests - awesome bar search       4
# 14      new awesomebar tests - awesome bar search       3
#
#                                        Title Preconditions  \
# 18                      URL Bar - Globe Icon           NaN
# 15                 Search State - Favorites            NaN
# 14  Search State - Favicons/Search Indicator           NaN
#
#                                                 Steps  \
# 18  1. Verify the Globe icon displays for Firefox ...
# 15  1. Ensure the star appears if the drop down di...
# 14  1. Ensure Favicons for sites are displayed - E...
#
#                                       Expected_Result    tc_name  \
# 18               1. The globe is correctly displayed.  TC_19_TRG
# 15  1. Search result has the star icon displayed\n...  TC_16_TRG
# 14  1. Favicon or search indicator icon is display...  TC_15_TRG
#
#                                               tc_desc
# 18  19 20160603 + 20160624 + 20161014 new awesomeb...
# 15  16 20160603 + 20160624 + 20161014 new awesomeb...
# 14  15 20160603 + 20160624 + 20161014 new awesomeb...

# %%
all_hyperparams = {
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : [('cosine' ,x)  for x in [.80]],
    LSI_Model_Hyperp.TOP.value : [10],
    LSI_Model_Hyperp.SVD_MODEL_N_COMPONENTS.value: [100],
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: [(1,1)],
    LSI_Model_Hyperp.VECTORIZER.value : [TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)],
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : [tok.WordNetBased_LemmaTokenizer()]
}

hyperparams = aux_functions.generate_params_comb_list(**all_hyperparams)          

print('Performing model hyperparameters search...')

def run_model(idx, **hyperp):    
    current_model = LSI(**hyperp)
    current_model.set_name('LSI_Model_{}'.format(idx))
    current_model.recover_links(corpus_subset, query_subset, testcases_names_subset, bug_reports_names_subset)
    
    evaluator = m_eval.ModelEvaluator(orc_subset_df, current_model)
    evaluator.evaluate_model()
    evaluator.dump_model()
    evaluator.dump_evaluator()
    
    return([evaluator.get_mean_precision(), 
            evaluator.get_mean_recall(),
            evaluator.get_mean_fscore(), 
            evaluator.get_model().get_name(),
            evaluator.get_model().get_top_value(),
            evaluator.get_model().get_vectorizer_type(), 
            evaluator.get_model().get_tokenizer_type(),
            evaluator.get_model().get_sim_measure_min_threshold()[0],
            evaluator.get_model().get_sim_measure_min_threshold()[1],
            evaluator.get_model().get_model_dump_path(),
            evaluator.get_evaluator_dump_path()
           ])

tasks = [(idx,hp) for idx,hp in enumerate(hyperparams)]
#results = Parallel(n_jobs=-1, verbose=1)(delayed(run_model)(idx, **hp) for idx,hp in tasks)
results = [run_model(t[0],**t[1]) for t in tasks]
results_df = pd.DataFrame(data=results, 
                          columns=['precision', 'recall', 'fscore', 'model_name', 'top_value', 'vectorizer', 'tokenizer', 'metric', 'metric_value', 'model_dump', 'evaluator_dump'])
results_df = results_df.astype(dtype={'model_dump' : str, 'evaluator_dump' : str})

bm = aux_functions.report_best_model(results_df)
bm.save_sim_matrix()

aux_functions.highlight_df(bm.get_trace_links_df())
# Out:
# Performing model hyperparameters search...
# ------------ Report -------------------
#
# Total of Analyzed Hyperparameters Combinations: 1
#
# Best Model Hyperparameters Combination Found:
#
# {'Measures': {'Mean FScore of LSI_Model_0': 0.016666666666666666,
#               'Mean Precision of LSI_Model_0': 0.06666666666666667,
#               'Mean Recall of LSI_Model_0': 0.009523809523809523},
#  'Setup': [{'Name': 'LSI_Model_0'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.8)},
#            {'Top Value': 10},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.WordNetBased_LemmaTokenizer object at 0x7f812a8a05f8>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# <style  type="text/css" >
#     #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col10 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col11 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col13 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row0_col14 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col7 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col10 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col13 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row1_col14 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col9 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col11 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col12 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col13 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row2_col14 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col7 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col9 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col10 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col11 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col12 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col13 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row3_col14 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col7 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col9 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col10 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col11 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col12 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col13 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row4_col14 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1ac59170_2978_11e9_a9a4_1c4d707b05c5ro

# %%
aux_functions.highlight_df(orc_subset_df)
# Out:
# <style  type="text/css" >
#     #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col10 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col11 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col13 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row0_col14 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col0 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col7 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col8 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col10 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col13 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row1_col14 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col9 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col11 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col12 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col13 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row2_col14 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col0 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col7 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col8 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col9 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col10 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col11 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col12 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col13 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row3_col14 {
#             background-color:  #008000;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col7 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col9 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col10 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col11 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col12 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col13 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row4_col14 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_230f7490_2978_11e9_a9a4_1c4d707b05c5ro

# %% [markdown]
# ### Find The Best Model

# %%
all_hyperparams = {
    LSI_Model_Hyperp.SIM_MEASURE_MIN_THRESHOLD.value : [('cosine' ,x)  for x in [.75,.85,.95]],
                                                       #[('jaccard',x)  for x in [.30,.40]] +
                                                       #[('edit',   x)  for x in [.30,.50]],
    LSI_Model_Hyperp.TOP.value : [10],
    LSI_Model_Hyperp.SVD_MODEL_N_COMPONENTS.value: [5,10],
    LSI_Model_Hyperp.VECTORIZER_NGRAM_RANGE.value: [(1,1), (1,2)],
    LSI_Model_Hyperp.VECTORIZER.value : [TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True), 
                         CountVectorizer(stop_words='english')],
    LSI_Model_Hyperp.VECTORIZER_TOKENIZER.value : [tok.PorterStemmerBased_Tokenizer(), tok.LancasterStemmerBased_Tokenizer(), 
                                                   tok.WordNetBased_LemmaTokenizer(), tok.SnowballStemmerBased_Tokenizer()]
}

hyperparams = aux_functions.generate_params_comb_list(**all_hyperparams)          

print('Performing model hyperparameters search...')

def run_model(idx, **hyperp):    
    current_model = LSI(**hyperp)
    current_model.set_name('LSI_Model_{}'.format(idx))
    current_model.recover_links(corpus, query, test_cases_names, bug_reports_names)
    
    evaluator = m_eval.ModelEvaluator(orc.oracle, current_model)
    evaluator.evaluate_model()
    evaluator.dump_model()
    evaluator.dump_evaluator()
    
    return([evaluator.get_mean_precision(), 
            evaluator.get_mean_recall(),
            evaluator.get_mean_fscore(), 
            evaluator.get_model().get_name(),
            evaluator.get_model().get_top_value(),
            evaluator.get_model().get_vectorizer_type(), 
            evaluator.get_model().get_tokenizer_type(),
            evaluator.get_model().get_sim_measure_min_threshold()[0],
            evaluator.get_model().get_sim_measure_min_threshold()[1],
            evaluator.get_model().get_model_dump_path(),
            evaluator.get_evaluator_dump_path()
           ])

tasks = [(idx,hp) for idx,hp in enumerate(hyperparams)]
#results = Parallel(n_jobs=-1, verbose=1)(delayed(run_model)(idx, **hp) for idx,hp in tasks)
results = [run_model(t[0],**t[1]) for t in tasks]
results_df = pd.DataFrame(data=results, 
                          columns=['precision', 'recall', 'fscore', 'model_name', 'top_value', 'vectorizer', 'tokenizer', 'metric', 'metric_value', 'model_dump', 'evaluator_dump'])
results_df = results_df.astype(dtype={'model_dump' : str, 'evaluator_dump' : str})
# Out:
# Performing model hyperparameters search...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# exception calling callback for <Future at 0x7fd117ffee48 state=finished raised BrokenProcessPool>
# sklearn.externals.joblib.externals.loky.process_executor._RemoteTraceback:
# '''
# Traceback (most recent call last):
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 391, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/multiprocessing/queues.py", line 113, in get
#     return _ForkingPickler.loads(res)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/enum.py", line 135, in __new__
#     enum_members = {k: classdict[k] for k in classdict._member_names}
# AttributeError: 'dict' object has no attribute '_member_names'
# '''
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 510, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/reusable_executor.py", line 151, in submit
#     fn, *args, **kwargs)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 1022, in submit
#     raise self._flags.broken
# sklearn.externals.joblib.externals.loky.process_executor.BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# '''
# Traceback (most recent call last):
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 391, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/multiprocessing/queues.py", line 113, in get
#     return _ForkingPickler.loads(res)
#   File "/home/guilherme/anaconda3/envs/trace-link-recovery-study/lib/python3.6/enum.py", line 135, in __new__
#     enum_members = {k: classdict[k] for k in classdict._member_names}
# AttributeError: 'dict' object has no attribute '_member_names'
# '''
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-22-5222442358eb> in <module>()
#      40
#      41 tasks = [(idx,hp) for idx,hp in enumerate(hyperparams)]
# ---> 42 results = Parallel(n_jobs=-1, verbose=1)(delayed(run_model)(idx, **hp) for idx,hp in tasks)
#      43 #results = [run_model(t[0],**t[1]) for t in tasks]
#      44 results_df = pd.DataFrame(data=results,
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/_base.py in _invoke_callbacks(self)
#     623         for callback in self._done_callbacks:
#     624             try:
# --> 625                 callback(self)
#     626             except BaseException:
#     627                 LOGGER.exception('exception calling callback for %r', self)
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, out)
#     307         with self.parallel._lock:
#     308             if self.parallel._original_iterator is not None:
# --> 309                 self.parallel.dispatch_next()
#     310
#     311
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_next(self)
#     729
#     730         """
# --> 731         if not self.dispatch_one_batch(self._original_iterator):
#     732             self._iterating = False
#     733             self._original_iterator = None
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     508     def apply_async(self, func, callback=None):
#     509         """Schedule a func to be run"""
# --> 510         future = self._workers.submit(SafeFunction(func))
#     511         future.get = functools.partial(self.wrap_future_result, future)
#     512         if callback is not None:
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/reusable_executor.py in submit(self, fn, *args, **kwargs)
#     149         with self._submit_resize_lock:
#     150             return super(_ReusablePoolExecutor, self).submit(
# --> 151                 fn, *args, **kwargs)
#     152
#     153     def _resize(self, max_workers):
#
# ~/anaconda3/envs/trace-link-recovery-study/lib/python3.6/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py in submit(self, fn, *args, **kwargs)
#    1020         with self._flags.shutdown_lock:
#    1021             if self._flags.broken is not None:
# -> 1022                 raise self._flags.broken
#    1023             if self._flags.shutdown:
#    1024                 raise ShutdownExecutorError(
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %% [markdown]
# ### Report

# %%
bm = aux_functions.report_best_model(results_df)
# Out:
# ------------ Report -------------------
#
# Total of Analyzed Hyperparameters Combinations: 1
#
# Best Model Hyperparameters Combination Found:
#
# {'Measures': {'Mean FScore of LSI_Model_0': 0.0,
#               'Mean Precision of LSI_Model_0': 0.0,
#               'Mean Recall of LSI_Model_0': 0.0},
#  'Setup': [{'Name': 'LSI_Model_0'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.8)},
#            {'Top Value': 10},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 100,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.float64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.WordNetBased_LemmaTokenizer object at 0x7f5713aa0860>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}

# %% [markdown]
# #### Save Similarity Matrix

# %%
bm.save_sim_matrix()

# %% [markdown]
# #### Best Model for TOP 3 and 5 - Cosine

# %%
aux_functions.print_report_top_3_and_5_v3(results_df, SimilarityMeasure.COSINE.value)
# Out:
# {'Measures': {'Mean FScore of LSI_Model_8': 0.5833333333333334,
#               'Mean Precision of LSI_Model_8': 0.48809523809523814,
#               'Mean Recall of LSI_Model_8': 0.7976190476190476},
#  'Setup': [{'Name': 'LSI_Model_8'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.75)},
#            {'Top Value': 3},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 5,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.int64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 2),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.PorterStemmerBased_Tokenizer object at 0x7fef81d74748>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# ------------------------------------------------------------------
# {'Measures': {'Mean FScore of LSI_Model_32': 0.5916666666666667,
#               'Mean Precision of LSI_Model_32': 0.4678571428571429,
#               'Mean Recall of LSI_Model_32': 0.9285714285714286},
#  'Setup': [{'Name': 'LSI_Model_32'},
#            {'Similarity Measure and Minimum Threshold': ('cosine', 0.75)},
#            {'Top Value': 5},
#            {'SVD Model': {'algorithm': 'randomized',
#                           'n_components': 5,
#                           'n_iter': 10,
#                           'random_state': 42,
#                           'tol': 0.0}},
#            {'Vectorizer': {'analyzer': 'word',
#                            'binary': False,
#                            'decode_error': 'strict',
#                            'dtype': <class 'numpy.int64'>,
#                            'encoding': 'utf-8',
#                            'input': 'content',
#                            'lowercase': True,
#                            'max_df': 1.0,
#                            'max_features': None,
#                            'min_df': 1,
#                            'ngram_range': (1, 1),
#                            'norm': 'l2',
#                            'preprocessor': None,
#                            'smooth_idf': True,
#                            'stop_words': 'english',
#                            'strip_accents': None,
#                            'sublinear_tf': False,
#                            'token_pattern': '(?u)\\b\\w\\w+\\b',
#                            'tokenizer': <utils.tokenizers.PorterStemmerBased_Tokenizer object at 0x7fef7d0936d8>,
#                            'use_idf': True,
#                            'vocabulary': None}},
#            {'Vectorizer Type': <class 'sklearn.feature_extraction.text.TfidfVectorizer'>}]}
# ------------------------------------------------------------------

# %% [markdown]
# #### Best Model for TOP 3 and 5 - Jaccard

# %%
#aux_functions.print_report_top_3_and_5_v3(results_df, SimilarityMeasure.JACCARD_INDEX.value)

# %% [markdown]
# #### Best Model for Top 3 and 5 - Edit Distance

# %%
#aux_functions.print_report_top_3_and_5_v3(results_df, SimilarityMeasure.EDIT_DISTANCE.value)

# %% [markdown]
# ### Plot Highlights

# %%
aux_functions.highlight_df(best_model.get_trace_links_df())
# Out:
# <style  type="text/css" >
#     #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row0_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col10 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row1_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col2 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col5 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col8 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col9 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row2_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col0 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col1 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col4 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col5 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col6 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col7 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col11 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row3_col13 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col0 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col1 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col4 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col5 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col6 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col7 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col11 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row4_col13 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_col0 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_col1 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_col3 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_col4 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_col5 {
#             background-color:  #008000;
#         }    #T_6912153e_f7ea_11e8_a08b_1c4d707b05c5row5_co

# %%
aux_functions.highlight_df(orc.oracle)
# Out:
# <style  type="text/css" >
#     #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row0_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col10 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row1_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col2 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row2_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col4 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col7 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col11 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row3_col13 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col0 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col1 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col3 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col4 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col7 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col9 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col10 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col11 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col12 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row4_col13 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_col5 {
#             background-color:  #008000;
#         }    #T_6912153f_f7ea_11e8_a08b_1c4d707b05c5row5_co
