# %%
import pandas as pd

testcases = pd.read_csv('../data/mozilla_firefox/firefoxDataset/docs_english/TC/script/testcases.csv')
testcases.shape
# Out:
# (207, 8)

# %%
testcases.head(10)
# Out:
#    TC Number  Test Day                                         Gen. Title  \
# 0          1  20181221  <notificationbox> \nand\n <notification>\n cha...
# 1          2  20181221  <notificationbox> \nand\n <notification>\n cha...
# 2          3  20181221  <notificationbox> \nand\n <notification>\n cha...
# 3          4  20181221  <notificationbox> \nand\n <notification>\n cha...
# 4          5  20181221  <notificationbox> \nand\n <notification>\n cha...
# 5          6  20181221                                   update directory
# 6          7  20181221                                   update directory
# 7          8  20181221                                   update directory
# 8          9  20181221                                   update directory
# 9         10  20181221                                   update directory
#
#    Crt. Nr.                                              Title  \
# 0         1                         Notification - Popup Block
# 1         2                        Notification - Process Hang
# 2         3            Verify Notifications appear in RTL Mode
# 3         4  Verify Notifications appear in High Contrast M...
# 4         5  Verify notifications react to differing Zoom l...
# 5         1  Update the Firefox application to the latest u...
# 6         2                               New Update directory
# 7         3       Pending updates can be resumed by other user
# 8         4  Closing Firefox without update can be resumed ...
# 9         5               Old update data in the new directory
#
#                                        Preconditions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  "NO current installed version of Firefox Beta/...
# 8  NO current installed version of Firefox Beta/N...
# 9                                                NaN
#
#                                                Steps  \
# 0  1. Launch Firefox\n2. Navigate to http://www.p...
# 1  1. Launch Firefox\n2. In the URL bar, navigate...
# 2  1. Launch Firefox\n2. In about:config, change ...
# 3  1. While the browser is in High Contrast Mode,...
# 4  1. While the browser is in High Contrast Mode,...
# 5  1. Launch Firefox with new profile(older beta ...
# 6  1. Launch Firefox with new profile (older beta...
# 7  1. Launch Firefox (older beta after Dec 10th, ...
# 8  1. Launch Firefox with new profile (older beta...
# 9  1. Launch Firefox with new profile (older beta...
#
#                                      Expected Result
# 0  1. Firefox is successfully launched\n9. The al...
# 1  1. Firefox is successfully launched\n2. Firefo...
# 2  1. Firefox is successfully launched\n2.The for...
# 3  1. Firefox has been launched.\n2. Firefox begi...
# 4  1. Firefox has been launched.\n2. Firefox begi...
# 5  1. Firefox opens.\n2. Firefox restarts.\n3. Fi...
# 6  1. Firefox opens.\n2. Firefox restarts.\n3. Fi...
# 7  1. Firefox opens.\n2. Firefox restarts.\n4. Up...
# 8  1. Firefox opens.\n2. Update status displays a...
# 9  1. Firefox starts.\n2. It may have some old da...

# %%
bugreports = pd.read_csv('../data/mozilla_firefox/firefoxDataset/docs_english/BR_2/all_bugs_p1.csv', sep="|")
bugreports.shape
# Out:
# (23033, 10)

# %%
bugreports_p2 = pd.read_csv('../data/mozilla_firefox/firefoxDataset/docs_english/BR_2/all_bugs_p2.csv', sep='|')
bugreports_p2.shape
# Out:
# (10239, 10)

# %%
bugreports_p3 = pd.read_csv('../data/mozilla_firefox/firefoxDataset/docs_english/BR_2/all_bugs_p3.csv', sep='|')
bugreports_p3.shape
# Out:
# (2683, 10)

# %% [markdown]
# **Merging bug reports dataframes**

# %%
br_df = pd.concat([bugreports, bugreports_p2, bugreports_p3])
br_df.shape
# Out:
# (35955, 10)

# %%
br_df.head(10)
# Out:
#    Bug_Number                                            Summary Platform  \
# 0      506297  Livemarks with null site/feed uris cause sync ...      All
# 1      506338     Enhance Crash Recovery to better help the user      All
# 2      506507  Dragging multiple bookmarks in the bookmarks s...      x86
# 3      506550      Unreliable Back Button navigating nytimes.com      x86
# 4      506575  ALT + F4 when dropdown of autocomplete is open...      x86
# 5      506729  Observe system information service for power s...      All
# 6      506768  Use relative bookmark positioning to not requi...      All
# 7      506795                     Handle adding duplicate logins      All
# 8      506820  Apply incoming record after detecting records ...      All
# 9      506831  When reconciling, have the tracker ignore chan...      All
#
#                  Component      Version         Creation_Time  \
# 0                     Sync  unspecified  2009-07-24T17:08:43Z
# 1          Session Restore        Trunk  2009-07-24T19:17:21Z
# 2      Bookmarks & History        Trunk  2009-07-26T06:16:02Z
# 3  Extension Compatibility   3.5 Branch  2009-07-26T16:12:10Z
# 4              Address Bar   3.5 Branch  2009-07-26T20:14:54Z
# 5                     Sync  unspecified  2009-07-27T20:12:25Z
# 6                     Sync  unspecified  2009-07-27T22:14:25Z
# 7                     Sync  unspecified  2009-07-27T23:50:14Z
# 8                     Sync  unspecified  2009-07-28T01:17:15Z
# 9                     Sync  unspecified  2009-07-28T02:04:16Z
#
#                                        Whiteboard QA_Whiteboard  \
# 0                                             NaN           NaN
# 1                  [crashkill][crashkill-metrics]           NaN
# 2                                             NaN           NaN
# 3  [caused by adblock plus][platform-rel-NYTimes]           NaN
# 4                                             NaN           NaN
# 5                                             NaN           NaN
# 6                                             NaN           NaN
# 7                                             NaN           NaN
# 8                                           [qa-]           NaN
# 9                            [needs verification]           NaN
#
#                                   First_Comment_Text  \
# 0  2009-07-24 09:54:28     FaultTolerance       D...
# 1  When our users crash they are pretty much in t...
# 2  User-Agent:       Mozilla/5.0 (Windows; U; Win...
# 3  User-Agent:       Mozilla/5.0 (Windows; U; Win...
# 4  Pressing ALT + F4 when the autocomplete dropdo...
# 5  We probably want to sync less aggressively whe...
# 6  Right now bookmarks require the server to give...
# 7  Users can get warning messages when a login is...
# 8  Right now _reconcile returns false to indicate...
# 9  store.changeItemID can cause trackers to get n...
#
#   First_Comment_Creation_Time
# 0        2009-07-24T17:08:43Z
# 1        2009-07-24T19:17:21Z
# 2        2009-07-26T06:16:02Z
# 3        2009-07-26T16:12:10Z
# 4        2009-07-26T20:14:54Z
# 5        2009-07-27T20:12:25Z
# 6        2009-07-27T22:14:25Z
# 7        2009-07-27T23:50:14Z
# 8        2009-07-28T01:17:15Z
# 9        2009-07-28T02:04:16Z
